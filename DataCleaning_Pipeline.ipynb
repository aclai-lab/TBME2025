# %%
# LIBRARIES
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import shutil
import math
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import re
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import shapiro
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix
from deap import base, creator, tools, algorithms
import pickle

# %%
if not os.path.exists('ResidualProducts'):
    os.makedirs('ResidualProducts')

# %%
def plot_histogram_with_binning(dataset, title="Histogram of Values", xlabel="Values", ylabel="Frequency", filename="filename.jpg"):
    """
    Creates a histogram for the data in the second column of the dataset.
    Performs sensible binning based on the range of values.

    Args:
        dataset (pd.DataFrame): Dataset with at least two columns: the first is the identifier,
                                the second is the value to plot.
        title (str): Title of the plot.
        xlabel (str): Label for the x-axis.
        ylabel (str): Label for the y-axis.
    """
    # Ensure the dataset has at least two columns
    if dataset.shape[1] < 2:
        raise ValueError("The dataset must have at least two columns.")

    # Extract values from the second column
    values = dataset.iloc[:, 1]

    # Determine the range of values
    min_val = values.min()
    max_val = values.max()

      # Determine bin size based on the range and data type
    range_span = max_val - min_val
    if values.apply(float.is_integer).all() and range_span <= 100:  # Suitable for integers with small range
        num_bins = int(range_span + 1)
    else:
        bin_size = 0.01 if range_span > 1 else range_span / 100  # Adapt bin size dynamically
        num_bins = max(int(range_span / bin_size), 1)  # Ensure at least 1 bin

    # Create the histogram
    plt.figure(figsize=(10, 6))
    plt.hist(values, bins=num_bins, edgecolor='black', alpha=0.7)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.savefig(filename)

    # Show the plot
    plt.show()

# %%
def calculate_durations(directory):
    """
    This method calculates the durations of data recording for each CSV file in a given directory.
    It assumes that the data is sampled at 12.5 Hz and calculates the duration based on the number of rows in each file.
    Files named 'blank.csv' are ignored. The method returns a sorted DataFrame containing filenames and their respective durations.
    
    Args:
        directory (str): The path to the directory containing the CSV files.
    
    Returns:
        pandas.DataFrame: A DataFrame with two columns:
                          - 'File': The name of each processed CSV file.
                          - 'Duration': The calculated duration for each file (in seconds).
    """
    durations = []
    filenames = []

    # Iterate over all files in the directory
    for file in os.listdir(directory):
        if file.endswith(".csv"):
            if not file.endswith("blank.csv"):
                filepath = os.path.join(directory, file)

                # Read the CSV file and count the number of rows
                try:
                    data = pd.read_csv(filepath)
                    duration = len(data) / 12.5  # Calculate duration based on 12.5 Hz sampling rate

                    # Store the result
                    durations.append(duration)
                    filenames.append(file)
                except Exception as e:
                    print(f"Error reading the file {file}: {e}")

    # Create a DataFrame with the results
    df = pd.DataFrame({
        'File': filenames,
        'Duration': durations
    })

    # Sort the DataFrame by duration in ascending order and reset the index
    df = df.sort_values(by='Duration', ascending=True).reset_index(drop=True)
    return df

# %%
def copy_files_from_dataframe(df, sourcedir, destinationdir):
    """
    Copies files listed in a DataFrame from a source directory to a destination directory.
    
    Args:
        df (pd.DataFrame): DataFrame containing the filenames to be copied.
        sourcedir (str): Path to the source directory.
        destinationdir (str): Path to the destination directory.
        'File' (str): Name of the column containing the filenames. Default: 'File'.
    
    Returns:
        None
    """
    if 'File' not in df.columns:
        raise ValueError(f"The column 'File' does not exist in the DataFrame.")
    
    # Create the destination directory if it does not exist
    if not os.path.exists(destinationdir):
        os.makedirs(destinationdir)
    
    # Counters for copied and missing files
    files_copied = 0
    files_missing = 0
    
    for file in df['File']:
        source_path = os.path.join(sourcedir, file)
        destination_path = os.path.join(destinationdir, file)
        
        if os.path.exists(source_path):
            shutil.copy2(source_path, destination_path)  # Copy while preserving metadata
            files_copied += 1
        else:
            print(f"File not found: {source_path}")
            files_missing += 1
    
    print(f"Operation completed: {files_copied} files copied, {files_missing} files missing.")

# %%
def plot_duration_distribution(durations_df):
    """
    This method generates a plot displaying the distribution of durations for trials.
    It plots the trial indices on the x-axis and their corresponding durations on the y-axis.
    Vertical lines mark the 5th and 95th percentiles, while horizontal lines indicate the corresponding durations.
    The plot is saved as a JPEG file and displayed.

    Args:
        durations_df (pandas.DataFrame): A DataFrame containing two columns:
                                         - 'index': The trial indices (implicit as DataFrame index).
                                         - 'Duration': The durations for each trial.
    """
    plt.figure(figsize=(12, 8))
    
    # Create a plot with trials on the x-axis and duration on the y-axis
    plt.plot(durations_df.index, durations_df['Duration'], marker=".", alpha=0.7)
    plt.yticks(range(int(durations_df['Duration'].min()), int(durations_df['Duration'].max()), 5))

    length = len(durations_df)
    dur_05 = int(length * 0.05)
    dur_95 = int(length * 0.95)

    # Find y-values corresponding to the vertical lines
    y_5th = durations_df['Duration'].iloc[dur_05]
    y_95th = durations_df['Duration'].iloc[dur_95]

    # Vertical line for the 5th percentile
    plt.axvline(x=dur_05, color='red', linestyle='--', label='5th-Percentile')
    
    # Vertical line for the 95th percentile
    plt.axvline(x=dur_95, color='red', linestyle='--', label='95th-Percentile')

    # Thin black horizontal lines
    plt.axhline(y=y_5th, color='black', linestyle='-', linewidth=0.7)
    plt.axhline(y=y_95th, color='black', linestyle='-', linewidth=0.7)

    plt.title("Trial Ascending Duration Plot", fontsize=16)
    plt.xlabel("Trial (enum)", fontsize=14)
    plt.ylabel("Duration (seconds)", fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()

    # Save and display the plot
    plt.savefig("ResidualProducts/Plot_Durate_Trials_Ordinate_RAW.jpg")
    plt.show()

# %%
def plot_duration_distribution_filtered(durations_df):
    """
    Plots the distribution of trial durations after filtering based on pupil confidence.
    
    Args:
        durations_df (pd.DataFrame): A DataFrame containing trial durations, indexed by trial number, with a 'Duration' column.
    
    Returns:
        None
    """
    plt.figure(figsize=(12, 8))
    
    # Plot trials on the x-axis and durations on the y-axis
    plt.plot(durations_df.index, durations_df['Duration'], marker=".", alpha=0.7)
    plt.yticks(range(int(durations_df['Duration'].min()), int(durations_df['Duration'].max()), 5))

    length = len(durations_df)
    dur_10 = int(length * 0.05)  # Calculate the 5th percentile index

    # Get the y-value corresponding to the 5th percentile line
    y_10th = durations_df['Duration'].iloc[dur_10]

    # Add a vertical line for the 5th percentile
    plt.axvline(x=dur_10, color='red', linestyle='--', label='5th Percentile')

    # Add a horizontal line at the y-value of the 5th percentile
    plt.axhline(y=y_10th, color='black', linestyle='-', linewidth=0.7)

    # Title and labels
    plt.title("Trial Ascending Duration Plot After Pupil-Confidence Cleaning", fontsize=16)
    plt.xlabel("Trial (enum)", fontsize=14)
    plt.ylabel("Duration (seconds)", fontsize=14)

    # Add grid and legend
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()

    # Save and display the plot
    plt.savefig("ResidualProducts/Plot_Durations_Trials_Ascending_Filtered.jpg")
    plt.show()

# %%
def calculate_range_x(directory):
    """
    Calculates the range of the 'x' column for each CSV file in a specified directory.
    Caps the range at a maximum of 15 and outputs the results in a sorted CSV file.

    Args:
        directory (str): Path to the directory containing CSV files.

    Returns:
        pd.DataFrame: A DataFrame with two columns:
                      - 'File': The name of each processed CSV file.
                      - 'Range': The calculated range of the 'x' column for each file.
    """
    ranges = []
    filenames = []

    # Iterate through all files in the directory
    for file in os.listdir(directory):
        if file.endswith(".csv") and not file.endswith("blank.csv"):
            filepath = os.path.join(directory, file)

            # Read the CSV file and calculate the range of 'x'
            try:
                data = pd.read_csv(filepath)
                x_range = abs(data['x'].max() - data['x'].min())
                
                # Cap the range at a maximum of 15
                if x_range > 15:
                    x_range = 15
                
                # Store the result
                ranges.append(x_range)
                filenames.append(file)
                print(file)  # Log the processed file
            except Exception as e:
                print(f"Error reading file {file}: {e}")

    # Create a DataFrame with the results
    df = pd.DataFrame({
        'File': filenames,
        'Range': ranges
    })

    # Sort the DataFrame by range in ascending order and save to a CSV file
    df = df.sort_values(by='Range', ascending=True).reset_index(drop=True)
    df.to_csv("ResidualProducts/RangeOrderedTrials.csv", index=False)
    return df

# %%
def calculate_range_y(directory):
    """
    Calculates the range of the 'y' column for each CSV file in a specified directory.
    Caps the range at a maximum of 15 and outputs the results in a sorted CSV file.

    Args:
        directory (str): Path to the directory containing CSV files.

    Returns:
        pd.DataFrame: A DataFrame with two columns:
                      - 'File': The name of each processed CSV file.
                      - 'Range': The calculated range of the 'y' column for each file.
    """
    ranges = []
    filenames = []

    # Iterate through all files in the directory
    for file in os.listdir(directory):
        if file.endswith(".csv") and not file.endswith("blank.csv"):
            filepath = os.path.join(directory, file)

            # Read the CSV file and calculate the range of 'y'
            try:
                data = pd.read_csv(filepath)
                y_range = abs(data['y'].max() - data['y'].min())
                
                # Cap the range at a maximum of 15
                if y_range > 15:
                    y_range = 15
                
                # Store the result
                ranges.append(y_range)
                filenames.append(file)
                print(file)  # Log the processed file
            except Exception as e:
                print(f"Error reading file {file}: {e}")

    # Create a DataFrame with the results
    df = pd.DataFrame({
        'File': filenames,
        'Range': ranges
    })

    # Sort the DataFrame by range in ascending order and save to a CSV file
    df = df.sort_values(by='Range', ascending=True).reset_index(drop=True)
    df.to_csv("ResidualProducts/RangeOrderedTrials_Y.csv", index=False)
    return df

# %%
def plot_combined_range_distribution(ranges_df_x, ranges_df_y, threshold_x, threshold_y):
    """
    Plots the distribution of ranges for both 'x' and 'y' values for Files,
    and applies cuts based on the specified thresholds.

    Args:
        ranges_df_x (pd.DataFrame): DataFrame containing ranges of 'x' values.
        ranges_df_y (pd.DataFrame): DataFrame containing ranges of 'y' values.
        threshold_x (float): Threshold for cutting Files based on 'x' range.
        threshold_y (float): Threshold for cutting Files based on 'y' range.

    Returns:
        pd.DataFrame: DataFrame with Files categorized as kept or cut based on thresholds.
    """
    # Identify Files that exceed the thresholds
    cut_x = ranges_df_x[ranges_df_x['Range'] >= threshold_x]
    cut_y = ranges_df_y[ranges_df_y['Range'] >= threshold_y]

    # Files failing either x or y thresholds
    total_cut = pd.concat([cut_x, cut_y]).drop_duplicates()
    total_kept = ranges_df_x.merge(ranges_df_y, on='File').drop(total_cut.index, errors='ignore')

    # Plot x and y ranges with their thresholds
    plt.figure(figsize=(14, 8))
    
    # Plot x ranges
    plt.plot(ranges_df_x.index, ranges_df_x['Range'], label='X Range', marker=".", alpha=0.7, color='blue')
    plt.axhline(y=threshold_x, color='blue', linestyle='--', label=f'X Threshold ({threshold_x})')

    # Plot y ranges
    plt.plot(ranges_df_y.index, ranges_df_y['Range'], label='Y Range', marker=".", alpha=0.7, color='green')
    plt.axhline(y=threshold_y, color='green', linestyle='--', label=f'Y Threshold ({threshold_y})')

    # Add title and labels
    plt.title("Combined X and Y Range Distribution with Thresholds", fontsize=16)
    plt.xlabel("File (enum)", fontsize=14)
    plt.ylabel("Range", fontsize=14)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)

    # Save and show plot
    plt.tight_layout()
    plt.savefig("ResidualProducts/Combined_Range_Distribution_X_Y_Thresholds.jpg")
    plt.show()

    # Summary
    print(f"Total Files: {len(ranges_df_x)}")
    print(f"Files cut by X threshold: {len(cut_x)}")
    print(f"Files cut by Y threshold: {len(cut_y)}")
    print(f"Total Files cut: {len(total_cut)}")
    print(f"Total Files kept: {len(total_kept)}")

    # Return categorized DataFrame
    return pd.concat([
        total_cut.assign(Status='Cut'),
        total_kept.assign(Status='Kept')
    ])

# %%
def calculate_fixations(df, max_dispersion=15, min_duration_points=4):
    """
    This method identifies fixations from eye-tracking data using a dispersion-based algorithm.
    It calculates fixation statistics, including duration and pupil diameter metrics.

    Args:
        df (pandas.DataFrame): Input DataFrame containing at least the following columns:
                               - 'x': X-coordinates of gaze points.
                               - 'y': Y-coordinates of gaze points.
                               - 'DIAM': Pupil diameter values.
        max_dispersion (float): The maximum allowed dispersion (in pixels or units) for a set of points to be considered a fixation.
        min_duration_points (int): The minimum number of points required for a valid fixation.

    Returns:
        list of tuples: A list of tuples where each tuple represents a fixation with the following values:
                        - fixation_x (float): Mean x-coordinate of the fixation.
                        - fixation_y (float): Mean y-coordinate of the fixation.
                        - duration_fix (float): Duration of the fixation in milliseconds (calculated based on 13Hz sampling).
                        - min_diam (float): Minimum pupil diameter during the fixation.
                        - max_diam (float): Maximum pupil diameter during the fixation.
                        - mean_diam (float): Mean pupil diameter during the fixation.
                        - std_diam (float): Standard deviation of pupil diameter during the fixation.
    """
    fixations = []
    start_index = 0

    while start_index < len(df):
        # Initialize the current fixation
        current_fixation = [df.iloc[start_index]]
        i = start_index + 1

        while i < len(df):
            # Add the current point to the fixation if dispersion is within the threshold
            current_fixation.append(df.iloc[i])
            fixation_df = pd.DataFrame(current_fixation)

            # Check if the current dispersion exceeds the threshold
            if (fixation_df['x'].max() - fixation_df['x'].min() > max_dispersion or
                fixation_df['y'].max() - fixation_df['y'].min() > max_dispersion):
                # Remove the last point added if it exceeds the dispersion
                current_fixation.pop()
                break
            i += 1

        # Check if the fixation meets the minimum duration requirement
        if len(current_fixation) >= min_duration_points:
            fixation_df = pd.DataFrame(current_fixation)
            fixation_x = fixation_df['x'].mean()
            fixation_y = fixation_df['y'].mean()
            duration_fix = len(current_fixation) * 77  # 13Hz sampling rate translates to ~77ms per point
            min_diam = fixation_df['DIAM'].min()
            max_diam = fixation_df['DIAM'].max()
            mean_diam = fixation_df['DIAM'].mean()
            std_diam = fixation_df['DIAM'].std()
            fixations.append((fixation_x, fixation_y, duration_fix, min_diam, max_diam, mean_diam, std_diam))

        # Update the starting index for the next fixation
        start_index = i if i > start_index + 1 else start_index + 1

    return fixations

# %%
def analyze_list(data):
    """
    This method analyzes a list of fixations to calculate Areas of Interest (AOIs) using clustering.
    It determines the optimal number of clusters (k) using the silhouette score and performs k-means clustering on fixation coordinates.
    Each fixation is assigned to a cluster, and cluster centroids are computed and merged with the fixation data.

    Args:
        data (list of tuples): A list of fixations, where each tuple contains:
                               - x (float): X-coordinate of the fixation.
                               - y (float): Y-coordinate of the fixation.
                               - duration (float): Duration of the fixation in milliseconds.
                               - min_diam (float): Minimum pupil diameter during the fixation.
                               - max_diam (float): Maximum pupil diameter during the fixation.
                               - mean_diam (float): Mean pupil diameter during the fixation.
                               - std_diam (float): Standard deviation of pupil diameter during the fixation.

    Returns:
        pandas.DataFrame or None: A DataFrame containing fixation data with an additional 'cluster' column and centroid information,
                                  or None if clustering cannot be performed.
        int or None: The optimal number of clusters (k), or None if clustering cannot be performed.
    """
    # Create a DataFrame from the input data
    df = pd.DataFrame(data, columns=['x', 'y', 'duration', 'min_diam', 'max_diam', 'mean_diam', 'std_diam'])

    if len(df) < 2:
        print("Warning: Not enough data for clustering (len(df) < 2)")
        return None, None  # Not enough data for clustering

    max_k = int(np.sqrt(len(df)))  # Reasonable maximum for k
    silhouette_scores = {}

    for k in range(2, max_k + 1):
        kmeans = KMeans(n_clusters=k, random_state=42)
        labels = kmeans.fit_predict(df[['x', 'y']])  # Clustering based on x and y coordinates
        score = silhouette_score(df[['x', 'y']], labels)
        silhouette_scores[k] = score

    if not silhouette_scores:
        print("Warning: Skipping because non-meaningful silhouette score")
        return None, None  # Unable to calculate meaningful silhouette scores

    optimal_k = max(silhouette_scores, key=silhouette_scores.get)

    kmeans = KMeans(n_clusters=optimal_k, random_state=42)
    df['cluster'] = kmeans.fit_predict(df[['x', 'y']])  # Assign clusters based on x and y coordinates

    # Compute cluster centroids
    centroids = kmeans.cluster_centers_
    centroid_df = pd.DataFrame(centroids, columns=['x_centroid', 'y_centroid'])
    centroid_df['cluster'] = range(len(centroids))

    # Merge centroids with the fixation DataFrame
    df = df.merge(centroid_df, on='cluster', how='left')

    return df, optimal_k

# %%
def extract_static_gaze_features(df):
    """
    Extract static gaze features from a dataset where each trial contains gaze fixations
    with associated clusters (areas of interest) and fixation-level metrics.

    Parameters:
    df (pd.DataFrame): DataFrame with columns including 'x', 'y', 'duration',
                       'min_diam', 'max_diam', 'mean_diam', 'std_diam',
                       'cluster', 'x_centroid', 'y_centroid', and 'trial_id'.

    Returns:
    dict: A dictionary containing static gaze features for the trial.
    """
    # Initialize a dictionary to store the features
    features = {}

    # Total number of fixations in the trial
    total_fixations = len(df)

    # Count the number of unique areas of interest (clusters) visited
    areas_of_interest = df['cluster'].dropna().nunique()

    # Identify the initial and final area of interest (cluster)
    initial_area = df.iloc[0]['cluster']
    final_area = df.iloc[-1]['cluster']

    # Add a shifted column to detect transitions between clusters
    df['prev_cluster'] = df['cluster'].shift(1)

    # Calculate visits to the initial area
    visits_to_initial_area = ((df['prev_cluster'] != initial_area) & 
                              (df['cluster'] == initial_area)).sum()

    # Calculate visits to the final area
    visits_to_final_area = ((df['prev_cluster'] != final_area) & 
                            (df['cluster'] == final_area)).sum()

    # Add another shifted column to detect isolated fixations
    df['next_cluster'] = df['cluster'].shift(-1)

    # Count the number of isolated fixations (not preceded or followed by the same cluster)
    isolated_fixations = ((df['cluster'] != df['prev_cluster']) & 
                          (df['cluster'] != df['next_cluster'])).sum()

    # Group fixations by cluster and compute cumulative durations for each area
    cumulative_durations = df.groupby('cluster')['duration'].sum()

    # Calculate statistics for cumulative durations
    area_duration_min = cumulative_durations.min()
    area_duration_max = cumulative_durations.max()
    area_duration_mean = cumulative_durations.mean()
    area_duration_std = cumulative_durations.std()

    # Count the number of fixations per area
    num_fixations_per_area = df.groupby('cluster').size()

    # Statistics for the number of fixations per area
    min_fixations_per_area = num_fixations_per_area.min()
    max_fixations_per_area = num_fixations_per_area.max()
    mean_fixations_per_area = num_fixations_per_area.mean()
    std_fixations_per_area = num_fixations_per_area.std()

    # Find the last cluster and its consecutive fixations
    last_cluster = df.iloc[-1]['cluster']
    last_series = df[df['cluster'] == last_cluster].iloc[::-1]  # Reverse the order for cumulative calculation

    # Calculate the cumulative duration and count for the last cluster series
    last_series_duration = 0
    last_series_num_fixations = 0
    for _, row in last_series.iterrows():
        if row['cluster'] == last_cluster:
            last_series_duration += row['duration']
            last_series_num_fixations += 1
        else:
            break  # Exit when encountering a different cluster

    # Identify consecutive sequences of the same cluster
    df['sequence_id'] = (df['cluster'] != df['cluster'].shift(1)).cumsum()

    # Compress consecutive fixations in the same cluster into sequences
    compressed = df.groupby('sequence_id').agg({
        'cluster': 'first',  # Cluster ID
        'duration': 'sum',   # Cumulative duration
        'sequence_id': 'size'  # Number of fixations
    }).rename(columns={'sequence_id': 'num_fixations'}).reset_index(drop=True)

    # Extract information for the first and last sequences
    first_sequence = compressed.iloc[0]
    last_sequence = compressed.iloc[-1]

    # Identify the maximum duration and number of fixations among sequences
    max_duration = compressed['duration'].max()
    max_num_fixations = compressed['num_fixations'].max()

    # Binary features: check if the first/last sequence is the longest/most fixated
    first_is_longest_duration = first_sequence['duration'] == max_duration
    first_is_most_fixations = first_sequence['num_fixations'] == max_num_fixations
    last_is_longest_duration = last_sequence['duration'] == max_duration
    last_is_most_fixations = last_sequence['num_fixations'] == max_num_fixations

    # Calculate fixation-level duration statistics
    total_duration_fixations = df['duration'].sum()
    fixation_duration_min = df['duration'].min()
    fixation_duration_max = df['duration'].max()
    fixation_duration_mean = df['duration'].mean()
    fixation_duration_std = df['duration'].std()

    # Add features to the dictionary
    features = {
        "total_fixations": total_fixations,
        "areas_of_interest": areas_of_interest,
        "visits_to_final_area": visits_to_final_area,
        "isolated_fixations": isolated_fixations,
        "area_duration_min": area_duration_min,
        "area_duration_max": area_duration_max,
        "area_duration_mean": area_duration_mean,
        "area_duration_std": area_duration_std,
        "min_fixations_per_area": min_fixations_per_area,
        "max_fixations_per_area": max_fixations_per_area,
        "mean_fixations_per_area": mean_fixations_per_area,
        "std_fixations_per_area": std_fixations_per_area,
        "last_series_duration": last_series_duration,
        "last_series_num_fixations": last_series_num_fixations,
        "first_is_longest_duration": first_is_longest_duration,
        "first_is_most_fixations": first_is_most_fixations,
        "last_is_longest_duration": last_is_longest_duration,
        "last_is_most_fixations": last_is_most_fixations,
        "total_duration_fixations": total_duration_fixations,
        "fixation_duration_min": fixation_duration_min,
        "fixation_duration_max": fixation_duration_max,
        "fixation_duration_mean": fixation_duration_mean,
        "fixation_duration_std": fixation_duration_std
    }

    return features

# %%
def extract_static_pupil_features(df):
    """
    Extract static pupil features from a dataset of gaze fixations. 
    This includes metrics like dilation statistics, compressed cluster-level analysis,
    and properties of pupil dilation across sequences.

    Parameters:
    df (pd.DataFrame): DataFrame containing fixation data with columns such as 
                       'min_diam', 'max_diam', 'mean_diam', 'std_diam', and 'cluster'.

    Returns:
    dict: A dictionary containing the extracted static pupil features.
    """
    # **Dilation in the trial**
    # 1. Minimum of all minimum values
    min_diam = df['min_diam'].min()
    # 2. Maximum of all maximum values
    max_diam = df['max_diam'].max()
    # 3. Mean of all mean values
    mean_diam = df['mean_diam'].mean()
    # 4. Standard deviation of mean values
    std_diam = df['std_diam'].mean()

    # Add an identifier for consecutive sequences of the same cluster
    df['sequence_id'] = (df['cluster'] != df['cluster'].shift(1)).cumsum()

    # Compress fixations into consecutive sequences for the same cluster
    compressed = df.groupby('sequence_id').agg({
        'cluster': 'first',       # Cluster of the sequence
        'mean_diam': 'mean'       # Mean of the mean diameters in adjacent fixations
    }).reset_index(drop=True)

    # Compute cumulative mean diameter statistics for compressed areas
    min_diameter_compressed = compressed['mean_diam'].min()
    max_diameter_compressed = compressed['mean_diam'].max()
    mean_diameter_compressed = compressed['mean_diam'].mean()
    std_diameter_compressed = compressed['mean_diam'].std()

    # Compress fixations into sequences for the same cluster and compute min and max diameters
    compressed = df.groupby('sequence_id').agg({
        'cluster': 'first',        # Cluster of the sequence
        'min_diam': 'min',         # Minimum of the minimum diameters
        'max_diam': 'max'          # Maximum of the maximum diameters
    }).reset_index(drop=True)

    # Compute the range (max - min) of diameters for each compressed area
    compressed['diam_range'] = compressed['max_diam'] - compressed['min_diam']

    # Compute statistics for the diameter range
    diam_range_min = compressed['diam_range'].min()
    diam_range_max = compressed['diam_range'].max()
    diam_range_mean = compressed['diam_range'].mean()
    diam_range_std = compressed['diam_range'].std()

    # Compress fixations into sequences and compute mean diameters
    compressed = df.groupby('sequence_id').agg({
        'cluster': 'first',       # Cluster of the sequence
        'mean_diam': 'mean'       # Mean diameter in the sequence
    }).reset_index(drop=True)

    # Add an identifier for consecutive sequences of the same cluster
    df['sequence_id'] = (df['cluster'] != df['cluster'].shift(1)).cumsum()

    # Compress fixations into sequences and compute the maximum diameter
    compressed = df.groupby('sequence_id').agg({
        'cluster': 'first',       # Cluster of the sequence
        'max_diam': 'max'         # Maximum value of max_diam in the sequence
    }).reset_index(drop=True)

    # Find the global maximum value of max_diam
    global_max_diam = compressed['max_diam'].max()

    # Check if the maximum is in the first or last compressed area
    first_area_max = compressed.iloc[0]['max_diam'] == global_max_diam
    last_area_max = compressed.iloc[-1]['max_diam'] == global_max_diam

    # Create a dictionary with the extracted pupil features
    pupil_features = {
        # Dilation statistics for the trial
        "min_dilatation": min_diam,  # Minimum of all minimums
        "max_dilatation": max_diam,  # Maximum of all maximums
        "mean_dilatation": mean_diam,  # Mean of all means
        "std_dilatation": std_diam,  # Standard deviation of mean diameters

        # Compressed area-level cumulative mean diameter statistics
        "instance_area_mean_dilatation_min": min_diameter_compressed,  # Min of compressed mean diameters
        "instance_area_mean_dilatation_max": max_diameter_compressed,  # Max of compressed mean diameters
        "instance_area_mean_dilatation_mean": mean_diameter_compressed,  # Mean of compressed mean diameters
        "instance_area_mean_dilatation_std": std_diameter_compressed,  # Std of compressed mean diameters

        # Range (max - min) statistics for compressed areas
        "dilatation_range_min": diam_range_min,  # Minimum range
        "dilatation_range_max": diam_range_max,  # Maximum range
        "dilatation_range_mean": diam_range_mean,  # Mean range
        "dilatation_range_std": diam_range_std,  # Std of range

        # Boolean flags indicating if the global maximum diameter is in the first or last area
        "is_max_dilatation_in_first_instance_area": first_area_max,  # Is max in the first area? (True/False)
        "is_max_dilatation_in_last_instance_area": last_area_max  # Is max in the last area? (True/False)
    }

    return pupil_features

# %%
def extract_dynamic_gaze_features(df):
    """
    Extract dynamic gaze features from a dataset of gaze fixations. 
    This includes metrics related to the subject's behavior, such as returns to the initial area,
    fixation transitions, and sequences of consecutive fixations in clusters.

    Parameters:
    df (pd.DataFrame): DataFrame containing fixation data with columns such as 'cluster' and 'duration'.

    Returns:
    dict: A dictionary containing the extracted dynamic gaze features.
    """
    # Identify the initial area (cluster) from the first fixation
    initial_area = df.iloc[0]['cluster']

    # Check if the subject returns to the initial area after the first fixation
    returns_to_initial_area = df['cluster'].iloc[1:].isin([initial_area]).any()

    # Count the number of returns to the initial area
    areas = df['cluster'].values
    returns = 0
    for i in range(1, len(areas)):
        # If the previous area is not the initial area and the current area is the initial area
        if areas[i - 1] != initial_area and areas[i] == initial_area:
            returns += 1

    # Find the index of the first pair of consecutive fixations in the same cluster
    num_fixations_before_consecutive_clusters = next(
        (i for i in range(1, len(df)) if df['cluster'].iloc[i] == df['cluster'].iloc[i - 1]),
        len(df)  # If no consecutive pairs exist, return the total number of fixations
    )

    # Get the cluster of the first fixation
    first_cluster = df.iloc[0]['cluster']

    # Filter for the first series of fixations in the same cluster as the first fixation
    first_series = df[df['cluster'] == first_cluster].iloc[::-1]  # Reverse the order for cumulative calculations

    # Calculate the cumulative duration and count of fixations in the first series
    first_series_cumulative_duration = 0
    first_series_cumulative_nfixations = 0
    for _, row in first_series.iterrows():
        if row['cluster'] == first_cluster:
            first_series_cumulative_duration += row['duration']
            first_series_cumulative_nfixations += 1
        else:
            break  # Exit when encountering a fixation in a different cluster

    # Create a dictionary to store the extracted features
    gaze_features = {
        "returns_to_initial_area": returns_to_initial_area,  # Boolean indicating if there is any return
        "times_returns_to_initial_area": returns,  # Number of times the subject returns to the initial area
        "n_area_changes_before_first_long_area": num_fixations_before_consecutive_clusters,  # Fixations before a consecutive cluster
        "initial_instance_area_duration_ms": first_series_cumulative_duration,  # Duration of the first cluster series
        "initial_instance_area_n_fixations": first_series_cumulative_nfixations  # Number of fixations in the first cluster series
    }

    return gaze_features

# %%
eliminated = pd.DataFrame(columns=['File'])

# %%
# Directory containing the CSV files
directory = "coord_csv"  # 3628 trials - blanks (190) = 3438 valid trials

# Calculate the durations
durations_df = calculate_durations(directory)
durations_df.to_csv("ResidualProducts/trials_ascending_duration.csv", index=False)

# Display the DataFrame
print("Calculated durations:")
print(durations_df)

# Plot the distribution
plot_duration_distribution(durations_df)
plot_histogram_with_binning(durations_df, 'Durations Distribution', 'Durations', 'Frequency', 'ResidualProducts/DurationsHistogram.jpg')

# Calculate percentile thresholds
length = len(durations_df)
dur_05 = int(length * 0.05)  # 5th percentile index
dur_95 = int(length * 0.95)  # 95th percentile index

el1 = durations_df.head(dur_05)
el2 = durations_df.tail(dur_05)
el = pd.concat([el1, el2], ignore_index=True)

# Filter durations to exclude extreme values
durations_df = durations_df[dur_05:dur_95]

# Calculate summary statistics for the filtered DataFrame
dfmin = durations_df['Duration'].min()
dfmax = durations_df['Duration'].max()
dfmean = durations_df['Duration'].mean()
dfstd = durations_df['Duration'].std()

print(f"Min: {dfmin}\nMax: {dfmax}\nMean: {dfmean}\nStd: {dfstd}")

# Copy the files corresponding to the filtered durations
copy_files_from_dataframe(durations_df, 'coord_csv', 'ResidualProducts/csvPostDurationCleaning')
eliminated = pd.concat([eliminated, el['File']])
eliminated
# Out:
# Calculated durations:
#               File  Duration
# 0      S27_Q47.csv     45.60
# 1       S72_Q2.csv     48.88
# 2      S37_Q47.csv     49.04
# 3      S59_Q13.csv     50.00
# 4      S58_Q20.csv     50.32
# ...            ...       ...
# 3433   S329_Q1.csv    154.08
# 3434   S361_Q7.csv    157.84
# 3435   S48_Q23.csv    168.32
# 3436  S117_Q18.csv    183.84
# 3437  S264_Q11.csv    203.92
#
# [3438 rows x 2 columns]
# Min: 60.24
# Max: 136.96
# Mean: 90.99305977382876
# Std: 20.936814745215713
# Operation completed: 3095 files copied, 0 files missing.
#              File
# 0     S27_Q47.csv
# 1      S72_Q2.csv
# 2     S37_Q47.csv
# 3     S59_Q13.csv
# 4     S58_Q20.csv
# ..            ...
# 337   S329_Q1.csv
# 338   S361_Q7.csv
# 339   S48_Q23.csv
# 340  S117_Q18.csv
# 341  S264_Q11.csv
#
# [342 rows x 1 columns]

# %%
# Define folder paths
coord_csv_folder = 'ResidualProducts/csvPostDurationCleaning'
pupil_data_folder = 'PupilData'
output_folder = 'ResidualProducts/X-Y-Conf-Filtered'

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# List of files in the coord_csv folder
coord_csv_files = [f for f in os.listdir(coord_csv_folder) if f.endswith('.csv')]

for coord_file in coord_csv_files:
    # Full path of the coord_csv file
    coord_path = os.path.join(coord_csv_folder, coord_file)

    # Corresponding path in the PupilData folder
    pupil_path = os.path.join(pupil_data_folder, coord_file)

    # Check if the corresponding file exists in PupilData
    if not os.path.exists(pupil_path):
        print(f"Corresponding file not found for: {coord_file}")
        continue

    # Read the CSV files
    coord_df = pd.read_csv(coord_path)
    pupil_df = pd.read_csv(pupil_path)

    # Check if they have approximately the same number of rows
    if (len(coord_df) < (len(pupil_df) - 10)) or (len(coord_df) > (len(pupil_df) + 10)):
        print(f"Row count mismatch for {coord_file}: coord_csv ({len(coord_df)}), PupilData ({len(pupil_df)})")
        continue

    # Align the CONF value
    coord_df['CONF'] = pupil_df['CONF']
    coord_df['DIAM'] = pupil_df['DIAM']

    # Filter rows with CONF >= 0.75
    filtered_df = coord_df[coord_df['CONF'] >= 0.75][['x', 'y', 'DIAM']]

    # Save the filtered file in the output folder
    output_path = os.path.join(output_folder, coord_file)
    filtered_df.to_csv(output_path, index=False)

    print(f"File processed and saved: {output_path}")

print("Operation completed.")
# Out:
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S231_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S433_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S225_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S131_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S100_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S119_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S184_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S278_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S348_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S330_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S199_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S317_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S92_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S49_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S326_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S80_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S391_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S27_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S199_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S351_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S387_Q45.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S181_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S293_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S38_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S139_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S9_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S279_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S263_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S393_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S210_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S244_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S358_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S270_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S192_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S354_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S217_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S256_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S297_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S317_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S295_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S284_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S170_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S293_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S345_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S11_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S37_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S9_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S117_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S337_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S124_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S29_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S286_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S310_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S285_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S30_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S88_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S168_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S338_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S350_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S330_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S205_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S341_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S260_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S292_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S360_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S133_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S138_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S213_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S347_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S351_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S89_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S244_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S409_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S245_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S204_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S358_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S231_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S210_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S274_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S296_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S57_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S181_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S6_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S296_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S7_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S26_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S159_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S197_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S52_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S339_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S241_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S310_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S245_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S77_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S111_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S349_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S311_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S136_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S297_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S27_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S263_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S203_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S170_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S336_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S339_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S358_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S410_Q45.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S48_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S2_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S409_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S231_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S326_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S225_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S245_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S200_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S110_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S144_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S58_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S327_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S164_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S125_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S260_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S44_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S203_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S54_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S147_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S371_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S348_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S292_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S257_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S365_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S165_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S334_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S53_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S37_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S371_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S174_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S205_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S257_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S296_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S140_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S393_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S156_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S72_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S88_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S162_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S210_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S139_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S410_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S158_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S354_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S337_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S203_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S6_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S280_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S327_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S111_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S61_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S286_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S336_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S360_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S294_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S358_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S139_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S350_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S205_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S37_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S29_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S237_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S9_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S238_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S159_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S168_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S193_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S26_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S347_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S293_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S72_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S38_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S297_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S207_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S356_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S336_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S200_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S170_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S175_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S111_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S192_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S232_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S164_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S348_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S53_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S332_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S44_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S270_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S433_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S38_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S338_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S127_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S218_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S194_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S387_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S311_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S165_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S322_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S38_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S323_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S409_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S56_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S322_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S218_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S121_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S171_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S122_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S139_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S389_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S393_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S202_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/
Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S26_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S337_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S53_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S76_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S121_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S346_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S53_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S337_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S310_Q23.csv
# ...
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S88_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S38_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S310_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S323_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S204_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S165_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S349_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S410_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S30_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S212_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S206_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S376_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S348_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S263_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S294_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S237_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S27_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S327_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S409_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S86_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S222_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S237_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S371_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S25_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S197_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S257_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S350_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S209_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S327_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S48_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S274_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S8_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S156_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S326_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S360_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S326_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S257_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S168_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S394_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S391_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S294_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S271_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S330_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S357_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S206_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S121_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S57_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S334_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S339_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S199_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S157_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S295_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S164_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S111_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S349_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S44_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S203_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S132_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S183_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S171_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S85_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S110_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S412_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S412_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S277_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S205_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S88_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S277_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S1_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S333_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S202_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S337_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S159_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S202_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S210_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S238_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S232_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S144_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S49_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S138_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S387_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S28_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S413_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S121_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S326_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S6_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S2_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S6_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S202_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S339_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S229_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S310_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S220_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S200_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S171_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S334_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S413_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S331_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S12_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S270_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S207_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S244_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S391_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S216_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S413_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S337_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S341_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S202_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S274_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S163_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S286_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S292_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S293_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S168_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S238_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S6_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S410_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S27_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S231_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S354_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S56_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S332_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S199_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S86_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S72_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S158_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S404_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S37_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S356_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S409_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S311_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S412_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S168_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S121_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S387_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S138_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S119_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S26_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S124_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S293_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S26_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S76_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S164_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S409_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S354_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S350_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S193_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S334_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S1_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S197_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S357_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S230_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S257_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S389_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S198_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S169_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S285_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S169_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S341_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S389_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S7_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S2_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S310_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S212_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S221_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S357_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S157_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S91_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S394_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S270_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S57_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S284_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S274_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S196_Q23.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S277_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S12_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S238_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S292_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S144_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S54_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S349_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S291_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S119_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S127_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S351_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S256_Q18.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S280_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S217_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S88_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S274_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S412_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S232_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S193_Q15.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S209_Q6.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S224_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S279_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S27_Q4.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S211_Q20.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S6_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S433_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S270_Q7.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S136_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S49_Q11.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S291_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S156_Q14.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S229_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S371_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S322_Q2.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S330_Q21.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S157_Q9.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S336_Q22.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S54_Q10.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S394_Q47.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S174_Q16.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S8_Q13.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S295_Q1.csv
# File processed and saved: ResidualProducts/X-Y-Conf-Filtered/S197_Q18.csv
# Operation completed.

# %%
# Directory containing the filtered X-Y data
directory = "ResidualProducts/X-Y-Conf-Filtered"

# Calculate the durations
durations_df_filt = calculate_durations(directory)
durations_df_filt.to_csv("ResidualProducts/trials_ascending_duration_conf_filtered.csv", index=False)

# Display the DataFrame
print("Calculated durations:")
print(durations_df_filt)

# Plot the distribution
plot_duration_distribution_filtered(durations_df_filt)
plot_histogram_with_binning(
    durations_df_filt,
    'Confidence-Filtered Durations Distribution',
    'Durations',
    'Frequency',
    'ResidualProducts/Histogram_Durations_Filtered.jpg'
)

# Calculate the 5th percentile index
length = len(durations_df_filt)
dur_05 = int(length * 0.05)

el = durations_df_filt.head(dur_05)

# Filter the DataFrame to exclude the bottom 5% of durations
durations_df_filt = durations_df_filt[dur_05:]

# Calculate statistical metrics
dfmin = durations_df_filt['Duration'].min()
dfmax = durations_df_filt['Duration'].max()
dfmean = durations_df_filt['Duration'].mean()
dfstd = durations_df_filt['Duration'].std()

# Display statistics
print(f"Min: {dfmin}\nMax: {dfmax}\nMean: {dfmean}\nStd: {dfstd}")

# Copy files corresponding to the filtered durations
copy_files_from_dataframe(
    durations_df_filt,
    'ResidualProducts/X-Y-Conf-Filtered',
    'ResidualProducts/csvPostDurationPostFilteringPostDurationCleaning'
)

eliminated = pd.concat([eliminated, el['File']])
eliminated
# Out:
# Calculated durations:
#               File  Duration
# 0       S1_Q23.csv      0.08
# 1       S1_Q47.csv      0.08
# 2       S1_Q22.csv      0.08
# 3      S30_Q16.csv      0.16
# 4       S1_Q45.csv      0.24
# ...            ...       ...
# 3090  S291_Q13.csv    129.60
# 3091   S222_Q1.csv    129.84
# 3092  S332_Q22.csv    130.08
# 3093  S217_Q18.csv    130.32
# 3094  S365_Q18.csv    135.60
#
# [3095 rows x 2 columns]
# Min: 17.36
# Max: 135.6
# Mean: 71.62872492349541
# Std: 24.183908557169126
# Operation completed: 2941 files copied, 0 files missing.
#              File
# 0     S27_Q47.csv
# 1      S72_Q2.csv
# 2     S37_Q47.csv
# 3     S59_Q13.csv
# 4     S58_Q20.csv
# ..            ...
# 149   S280_Q2.csv
# 150   S280_Q6.csv
# 151   S210_Q1.csv
# 152  S244_Q18.csv
# 153  S199_Q15.csv
#
# [496 rows x 1 columns]

# %%
# Path to the directory containing the cleaned CSV files
source_folder = "ResidualProducts/csvPostDurationPostFilteringPostDurationCleaning"
destination_folder = "ResidualProducts/csvPostX-Y_RangeCleaning"

range_x_df = calculate_range_x(source_folder)
ranges_y_df = calculate_range_y(source_folder)
threshold_x = 15
threshold_y = 15

# Plot the range distribution and save the histogram
# Saves also the Kept-Cut dataframe list of files
df = plot_combined_range_distribution(range_x_df, ranges_y_df, threshold_x, threshold_y)

# Ensure the destination folder exists
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

el = df[df['Status'] == 'Cut']
# Iterate over the kept trials
kept_trials = df[df['Status'] == 'Kept']
for trial in kept_trials['File']:
    source_file = os.path.join(source_folder, f"{trial}")
    destination_file = os.path.join(destination_folder, f"{trial}")

    # Copy the file if it exists
    if os.path.exists(source_file):
        shutil.copy(source_file, destination_file)
    else:
        print(f"Source file {source_file} not found.")

print(f"Kept trials saved to {destination_folder}.")

eliminated = pd.concat([eliminated, el['File']])
eliminated
# Out:
# S231_Q23.csv
# S433_Q47.csv
# S225_Q47.csv
# S131_Q21.csv
# S100_Q7.csv
# S119_Q16.csv
# S184_Q7.csv
# S278_Q6.csv
# S348_Q13.csv
# S330_Q14.csv
# S199_Q4.csv
# S317_Q11.csv
# S92_Q23.csv
# S49_Q13.csv
# S80_Q7.csv
# S391_Q7.csv
# S27_Q11.csv
# S199_Q1.csv
# S351_Q16.csv
# S387_Q45.csv
# S181_Q18.csv
# S293_Q9.csv
# S38_Q11.csv
# S139_Q22.csv
# S9_Q21.csv
# S263_Q16.csv
# S393_Q13.csv
# S210_Q2.csv
# S244_Q6.csv
# S358_Q16.csv
# S270_Q11.csv
# S192_Q18.csv
# S354_Q47.csv
# S217_Q23.csv
# S256_Q6.csv
# S297_Q9.csv
# S317_Q21.csv
# S295_Q47.csv
# S284_Q15.csv
# S170_Q9.csv
# S293_Q23.csv
# S345_Q4.csv
# S11_Q7.csv
# S6_Q9.csv
# S433_Q2.csv
# S270_Q7.csv
# S136_Q2.csv
# S49_Q11.csv
# S291_Q9.csv
# S156_Q14.csv
# S229_Q2.csv
# S371_Q21.csv
# S322_Q2.csv
# S330_Q21.csv
# S157_Q9.csv
# S336_Q22.csv
# S54_Q10.csv
# S394_Q47.csv
# S174_Q16.csv
# S8_Q13.csv
# S295_Q1.csv
# S197_Q18.csv
# Total Files: 2941
# Files cut by X threshold: 158
# Files cut by Y threshold: 164
# Total Files cut: 176
# Total Files kept: 2783
# Kept trials saved to ResidualProducts/csvPostX-Y_RangeCleaning.
#               File
# 0      S27_Q47.csv
# 1       S72_Q2.csv
# 2      S37_Q47.csv
# 3      S59_Q13.csv
# 4      S58_Q20.csv
# ...            ...
# 2896   S39_Q23.csv
# 2901  S361_Q23.csv
# 2910  S117_Q23.csv
# 2925   S26_Q22.csv
# 2930    S39_Q2.csv
#
# [672 rows x 1 columns]

# %%
directory = "ResidualProducts/csvPostX-Y_RangeCleaning"
destination_folder = "ResidualProducts/Fixations-PreProcessing"

# Ensure the destination folder exists
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

for file in os.listdir(directory):
    if file.endswith(".csv"):
        try:
            # Parse subject ID and trial ID from the file name (format: S$s_Q$q.csv)
            parts = file.split('_')
            subject_id = parts[0][1:]  # Extract the subject ID (e.g., "S1" -> "1")
            trial_id = parts[1][1:-4]  # Extract the trial ID (e.g., "Q2.csv" -> "2")

            # Load the dataframe for the current trial
            dt = pd.read_csv(os.path.join(directory, file))

            # Calculate the standard deviations for x and y
            rng_x = dt['x'].max() - dt['x'].min()
            rng_y = dt['y'].max() - dt['y'].min()

            # Define thresholds for dispersion and duration
            dispersion_threshold = math.sqrt((rng_x / 20) ** 2 + (rng_y / 20) ** 2) / 2
            duration_threshold = 8

            # Calculate fixations on the dataset
            fixations = calculate_fixations(dt, max_dispersion=dispersion_threshold, min_duration_points=duration_threshold)

            # Analyze the fixation list and save the resulting DataFrame
            df, _ = analyze_list(fixations)

            # Save the analyzed data to the destination folder
            df.to_csv(os.path.join(destination_folder, file), index=False)

            print(f'Processed file: Subject {subject_id}, Trial {trial_id}')
        except Exception as e:
            print(f'Error processing file {file}: {e}')
# Out:
# Processed file: Subject 231, Trial 23
# Processed file: Subject 433, Trial 47
# Processed file: Subject 225, Trial 47
# Processed file: Subject 131, Trial 21
# Processed file: Subject 100, Trial 7
# Processed file: Subject 119, Trial 16
# Processed file: Subject 184, Trial 7
# Processed file: Subject 278, Trial 6
# Processed file: Subject 348, Trial 13
# Processed file: Subject 330, Trial 14
# Processed file: Subject 199, Trial 4
# Processed file: Subject 317, Trial 11
# Processed file: Subject 92, Trial 23
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S49_Q13.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 80, Trial 7
# Processed file: Subject 391, Trial 7
# Processed file: Subject 27, Trial 11
# Processed file: Subject 199, Trial 1
# Processed file: Subject 351, Trial 16
# Processed file: Subject 387, Trial 45
# Processed file: Subject 181, Trial 18
# Processed file: Subject 293, Trial 9
# Processed file: Subject 38, Trial 11
# Processed file: Subject 139, Trial 22
# Processed file: Subject 9, Trial 21
# Processed file: Subject 263, Trial 16
# Processed file: Subject 393, Trial 13
# Processed file: Subject 244, Trial 6
# Processed file: Subject 358, Trial 16
# Processed file: Subject 270, Trial 11
# Processed file: Subject 192, Trial 18
# Processed file: Subject 354, Trial 47
# Processed file: Subject 217, Trial 23
# Processed file: Subject 256, Trial 6
# Processed file: Subject 297, Trial 9
# Processed file: Subject 317, Trial 21
# Processed file: Subject 295, Trial 47
# Processed file: Subject 284, Trial 15
# Processed file: Subject 170, Trial 9
# Processed file: Subject 293, Trial 23
# Processed file: Subject 345, Trial 4
# Processed file: Subject 11, Trial 7
# Processed file: Subject 37, Trial 6
# Processed file: Subject 9, Trial 16
# Processed file: Subject 117, Trial 14
# Processed file: Subject 337, Trial 18
# Processed file: Subject 124, Trial 13
# Processed file: Subject 29, Trial 14
# Processed file: Subject 310, Trial 7
# Processed file: Subject 285, Trial 13
# Processed file: Subject 88, Trial 21
# Processed file: Subject 168, Trial 1
# Processed file: Subject 338, Trial 47
# Processed file: Subject 350, Trial 18
# Processed file: Subject 330, Trial 7
# Processed file: Subject 341, Trial 14
# Processed file: Subject 260, Trial 13
# Processed file: Subject 360, Trial 10
# Processed file: Subject 133, Trial 18
# Processed file: Subject 138, Trial 20
# Processed file: Subject 347, Trial 13
# Processed file: Subject 351, Trial 21
# Processed file: Subject 89, Trial 15
# Processed file: Subject 409, Trial 18
# Processed file: Subject 245, Trial 7
# Processed file: Subject 204, Trial 11
# Processed file: Subject 358, Trial 20
# Processed file: Subject 231, Trial 6
# Processed file: Subject 274, Trial 1
# Processed file: Subject 296, Trial 16
# Processed file: Subject 57, Trial 18
# Processed file: Subject 181, Trial 11
# Processed file: Subject 6, Trial 20
# Processed file: Subject 296, Trial 1
# Processed file: Subject 7, Trial 2
# Processed file: Subject 26, Trial 15
# Processed file: Subject 159, Trial 4
# Processed file: Subject 197, Trial 21
# Processed file: Subject 52, Trial 11
# Processed file: Subject 339, Trial 22
# Processed file: Subject 241, Trial 6
# Processed file: Subject 310, Trial 13
# Processed file: Subject 245, Trial 9
# Processed file: Subject 77, Trial 20
# Processed file: Subject 111, Trial 7
# Processed file: Subject 349, Trial 1
# Processed file: Subject 311, Trial 6
# Processed file: Subject 136, Trial 14
# Processed file: Subject 297, Trial 2
# Processed file: Subject 27, Trial 22
# Processed file: Subject 263, Trial 4
# Processed file: Subject 170, Trial 14
# Processed file: Subject 336, Trial 11
# Processed file: Subject 339, Trial 1
# Processed file: Subject 358, Trial 1
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S410_Q45.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 48, Trial 47
# Processed file: Subject 2, Trial 20
# Processed file: Subject 409, Trial 23
# Processed file: Subject 231, Trial 4
# Processed file: Subject 326, Trial 7
# Processed file: Subject 225, Trial 7
# Processed file: Subject 245, Trial 10
# Processed file: Subject 200, Trial 4
# Processed file: Subject 110, Trial 16
# Processed file: Subject 144, Trial 21
# Processed file: Subject 58, Trial 1
# Processed file: Subject 327, Trial 9
# Processed file: Subject 164, Trial 23
# Processed file: Subject 125, Trial 16
# Processed file: Subject 260, Trial 47
# Processed file: Subject 54, Trial 20
# Processed file: Subject 147, Trial 2
# Processed file: Subject 371, Trial 15
# Processed file: Subject 348, Trial 22
# Processed file: Subject 257, Trial 2
# Processed file: Subject 365, Trial 18
# Processed file: Subject 165, Trial 4
# Processed file: Subject 334, Trial 4
# Processed file: Subject 53, Trial 10
# Processed file: Subject 37, Trial 13
# Processed file: Subject 371, Trial 4
# Processed file: Subject 174, Trial 23
# Processed file: Subject 205, Trial 1
# Processed file: Subject 257, Trial 13
# Processed file: Subject 296, Trial 18
# Processed file: Subject 140, Trial 2
# Processed file: Subject 393, Trial 16
# Processed file: Subject 156, Trial 15
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S72_Q18.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 88, Trial 16
# Processed file: Subject 162, Trial 6
# Processed file: Subject 139, Trial 13
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S410_Q18.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 158, Trial 13
# Processed file: Subject 354, Trial 2
# Processed file: Subject 337, Trial 11
# Processed file: Subject 327, Trial 14
# Processed file: Subject 111, Trial 2
# Processed file: Subject 61, Trial 11
# Processed file: Subject 336, Trial 4
# Processed file: Subject 360, Trial 47
# Processed file: Subject 294, Trial 22
# Processed file: Subject 358, Trial 14
# Processed file: Subject 139, Trial 14
# Processed file: Subject 350, Trial 9
# Processed file: Subject 205, Trial 10
# Processed file: Subject 29, Trial 18
# Processed file: Subject 237, Trial 1
# Processed file: Subject 9, Trial 18
# Processed file: Subject 238, Trial 7
# Processed file: Subject 159, Trial 9
# Processed file: Subject 168, Trial 14
# Processed file: Subject 193, Trial 47
# Processed file: Subject 26, Trial 13
# Processed file: Subject 347, Trial 23
# Processed file: Subject 293, Trial 13
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S72_Q6.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 38, Trial 1
# Processed file: Subject 297, Trial 14
# Processed file: Subject 207, Trial 47
# Processed file: Subject 336, Trial 13
# Processed file: Subject 200, Trial 20
# Processed file: Subject 170, Trial 7
# Processed file: Subject 175, Trial 10
# Processed file: Subject 111, Trial 9
# Processed file: Subject 192, Trial 6
# Processed file: Subject 232, Trial 22
# Processed file: Subject 164, Trial 15
# Processed file: Subject 348, Trial 7
# Processed file: Subject 53, Trial 4
# Processed file: Subject 332, Trial 6
# Processed file: Subject 44, Trial 14
# Processed file: Subject 270, Trial 6
# Processed file: Subject 433, Trial 23
# Processed file: Subject 38, Trial 9
# Processed file: Subject 338, Trial 13
# Processed file: Subject 127, Trial 47
# Processed file: Subject 194, Trial 22
# Processed file: Subject 387, Trial 9
# Processed file: Subject 311, Trial 16
# Processed file: Subject 165, Trial 2
# Processed file: Subject 322, Trial 20
# Processed file: Subject 38, Trial 16
# Processed file: Subject 323, Trial 11
# Processed file: Subject 409, Trial 13
# Processed file: Subject 56, Trial 20
# Processed file: Subject 322, Trial 11
# Processed file: Subject 121, Trial 23
# Processed file: Subject 171, Trial 23
# Processed file: Subject 122, Trial 6
# Processed file: Subject 139, Trial 21
# Processed file: Subject 389, Trial 13
# Processed file: Subject 393, Trial 14
# Processed file: Subject 202, Trial 10
# Processed file: Subject 193, Trial 18
# Processed file: Subject 338, Trial 15
# Processed file: Subject 224, Trial 16
# Processed file: Subject 256, Trial 11
# Processed file: Subject 357, Trial 7
# Processed file: Subject 285, Trial 47
# Processed file: Subject 389, Trial 14
# Processed file: Subject 165, Trial 21
# Processed file: Subject 202, Trial 13
# Processed file: Subject 293, Trial 21
# Processed file: Subject 12, Trial 9
# Processed file: Subject 80, Trial 11
# Processed file: Subject 8, Trial 14
# Processed file: Subject 412, Trial 6
# Processed file: Subject 339, Trial 9
# Processed file: Subject 433, Trial 14
# Processed file: Subject 339, Trial 10
# Processed file: Subject 204, Trial 1
# Processed file: Subject 80, Trial 22
# Processed file: Subject 341, Trial 13
# Processed file: Subject 48, Trial 21
# Processed file: Subject 202, Trial 9
# Processed file: Subject 127, Trial 10
# Processed file: Subject 166, Trial 23
# Processed file: Subject 244, Trial 4
# Processed file: Subject 144, Trial 7
# Processed file: Subject 311, Trial 10
# Processed file: Subject 349, Trial 16
# Processed file: Subject 256, Trial 10
# Processed file: Subject 76, Trial 13
# Processed file: Subject 88, Trial 13
# Processed file: Subject 263, Trial 11
# Processed file: Subject 224, Trial 22
# Processed file: Subject 192, Trial 47
# Processed file: Subject 9, Trial 13
# Processed file: Subject 44, Trial 23
# Processed file: Subject 1, Trial 11
# Processed file: Subject 217, Trial 15
# Processed file: Subject 156, Trial 22
# Processed file: Subject 350, Trial 7
# Processed file: Subject 138, Trial 23
# Processed file: Subject 323, Trial 22
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S72_Q7.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 293, Trial 20
# Processed file: Subject 291, Trial 7
# Processed file: Subject 244, Trial 22
# Processed file: Subject 334, Trial 13
# Processed file: Subject 207, Trial 15
# Processed file: Subject 280, Trial 11
# Processed file: Subject 28, Trial 23
# Processed file: Subject 245, Trial 14
# Processed file: Subject 310, Trial 11
# Processed file: Subject 361, Trial 16
# Processed file: Subject 183, Trial 1
# Processed file: Subject 387, Trial 1
# Processed file: Subject 8, Trial 20
# Processed file: Subject 310, Trial 9
# Processed file: Subject 91, Trial 10
# Processed file: Subject 138, Trial 13
# Processed file: Subject 48, Trial 7
# Processed file: Subject 170, Trial 20
# Processed file: Subject 220, Trial 4
# Processed file: Subject 169, Trial 11
# Processed file: Subject 9, Trial 2
# Processed file: Subject 274, Trial 9
# Processed file: Subject 413, Trial 20
# Processed file: Subject 245, Trial 15
# Processed file: Subject 270, Trial 22
# Processed file: Subject 121, Trial 14
# Processed file: Subject 139, Trial 7
# Processed file: Subject 391, Trial 10
# Processed file: Subject 232, Trial 21
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S72_Q16.csv: 'NoneType' object has no attribute 'to_csv'
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S132_Q18.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 44, Trial 9
# Processed file: Subject 389, Trial 10
# Processed file: Subject 297, Trial 6
# Processed file: Subject 347, Trial 7
# Processed file: Subject 158, Trial 15
# Processed file: Subject 157, Trial 21
# Processed file: Subject 331, Trial 6
# Processed file: Subject 181, Trial 23
# Processed file: Subject 53, Trial 14
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S196_Q7.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 29, Trial 15
# Processed file: Subject 198, Trial 1
# Processed file: Subject 358, Trial 18
# Processed file: Subject 237, Trial 14
# Processed file: Subject 280, Trial 9
# Processed file: Subject 92, Trial 13
# Processed file: Subject 124, Trial 10
# Processed file: Subject 125, Trial 10
# Processed file: Subject 238, Trial 47
# Processed file: Subject 222, Trial 21
# Processed file: Subject 345, Trial 47
# Processed file: Subject 358, Trial 21
# Processed file: Subject 310, Trial 16
# Processed file: Subject 338, Trial 9
# Processed file: Subject 244, Trial 11
# Processed file: Subject 39, Trial 6
# Processed file: Subject 311, Trial 13
# Processed file: Subject 246, Trial 2
# Processed file: Subject 291, Trial 1
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S196_Q10.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 393, Trial 1
# Processed file: Subject 209, Trial 14
# Processed file: Subject 147, Trial 21
# Processed file: Subject 91, Trial 15
# Processed file: Subject 376, Trial 13
# Processed file: Subject 241, Trial 14
# Processed file: Subject 162, Trial 11
# Processed file: Subject 85, Trial 10
# Processed file: Subject 85, Trial 2
# Processed file: Subject 220, Trial 7
# Processed file: Subject 229, Trial 20
# Processed file: Subject 351, Trial 18
# Processed file: Subject 174, Trial 6
# Processed file: Subject 296, Trial 7
# Processed file: Subject 124, Trial 4
# Processed file: Subject 217, Trial 22
# Processed file: Subject 297, Trial 1
# Processed file: Subject 159, Trial 10
# Processed file: Subject 136, Trial 16
# Processed file: Subject 241, Trial 22
# Processed file: Subject 257, Trial 6
# Processed file: Subject 336, Trial 18
# Processed file: Subject 192, Trial 11
# Processed file: Subject 275, Trial 23
# Processed file: Subject 198, Trial 15
# Processed file: Subject 357, Trial 2
# Processed file: Subject 389, Trial 21
# Processed file: Subject 207, Trial 10
# Processed file: Subject 264, Trial 20
# Processed file: Subject 170, Trial 13
# Processed file: Subject 323, Trial 15
# Processed file: Subject 44, Trial 21
# Processed file: Subject 125, Trial 1
# Processed file: Subject 391, Trial 15
# Processed file: Subject 238, Trial 10
# Processed file: Subject 133, Trial 22
# Processed file: Subject 388, Trial 13
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S356_Q20.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 203, Trial 1
# Processed file: Subject 260, Trial 23
# Processed file: Subject 346, Trial 15
# Processed file: Subject 260, Trial 22
# Processed file: Subject 361, Trial 13
# Processed file: Subject 48, Trial 18
# Processed file: Subject 131, Trial 6
# Processed file: Subject 394, Trial 7
# Processed file: Subject 237, Trial 2
# Processed file: Subject 118, Trial 15
# Processed file: Subject 88, Trial 14
# Processed file: Subject 85, Trial 6
# Processed file: Subject 53, Trial 13
# Processed file: Subject 413, Trial 47
# Processed file: Subject 184, Trial 47
# Processed file: Subject 217, Trial 20
# Processed file: Subject 332, Trial 13
# Processed file: Subject 163, Trial 23
# Processed file: Subject 144, Trial 23
# Processed file: Subject 339, Trial 23
# Processed file: Subject 349, Trial 15
# Processed file: Subject 354, Trial 1
# Processed file: Subject 25, Trial 47
# Processed file: Subject 202, Trial 14
# Processed file: Subject 183, Trial 16
# Processed file: Subject 131, Trial 20
# Processed file: Subject 125, Trial 23
# Processed file: Subject 388, Trial 6
# Processed file: Subject 297, Trial 13
# Processed file: Subject 166, Trial 6
# Processed file: Subject 159, Trial 22
# Processed file: Subject 215, Trial 16
# Processed file: Subject 164, Trial 1
# Processed file: Subject 89, Trial 47
# Processed file: Subject 25, Trial 11
# Processed file: Subject 174, Trial 20
# Processed file: Subject 291, Trial 21
# Processed file: Subject 331, Trial 16
# Processed file: Subject 209, Trial 22
# Processed file: Subject 92, Trial 20
# Processed file: Subject 131, Trial 14
# Processed file: Subject 159, Trial 21
# Processed file: Subject 337, Trial 15
# Processed file: Subject 159, Trial 1
# Processed file: Subject 122, Trial 20
# Processed file: Subject 225, Trial 14
# Processed file: Subject 86, Trial 1
# Processed file: Subject 147, Trial 1
# Processed file: Subject 25, Trial 21
# Processed file: Subject 349, Trial 9
# Processed file: Subject 122, Trial 7
# Processed file: Subject 229, Trial 4
# Processed file: Subject 53, Trial 15
# Processed file: Subject 334, Trial 11
# Processed file: Subject 337, Trial 21
# Processed file: Subject 285, Trial 20
# Processed file: Subject 12, Trial 2
# Processed file: Subject 244, Trial 14
# Processed file: Subject 170, Trial 16
# Processed file: Subject 158, Trial 18
# Processed file: Subject 127, Trial 9
# Processed file: Subject 323, Trial 21
# Processed file: Subject 48, Trial 20
# Processed file: Subject 361, Trial 22
# Processed file: Subject 338, Trial 7
# Processed file: Subject 345, Trial 1
# Processed file: Subject 215, Trial 14
# Processed file: Subject 270, Trial 1
# Processed file: Subject 181, Trial 13
# Processed file: Subject 271, Trial 6
# Processed file: Subject 26, Trial 6
# Processed file: Subject 8, Trial 9
# Processed file: Subject 260, Trial 21
# Processed file: Subject 257, Trial 18
# Processed file: Subject 433, Trial 15
# Processed file: Subject 100, Trial 45
# Processed file: Subject 136, Trial 18
# Processed file: Subject 232, Trial 13
# Processed file: Subject 159, Trial 11
# Processed file: Subject 132, Trial 20
# Processed file: Subject 88, Trial 6
# Processed file: Subject 54, Trial 9
# Processed file: Subject 199, Trial 6
# Processed file: Subject 229, Trial 9
# Processed file: Subject 387, Trial 23
# Processed file: Subject 341, Trial 21
# Processed file: Subject 92, Trial 47
# Processed file: Subject 158, Trial 23
# Processed file: Subject 57, Trial 21
# Processed file: Subject 322, Trial 15
# Processed file: Subject 346, Trial 7
# Processed file: Subject 199, Trial 2
# Processed file: Subject 274, Trial 22
# Processed file: Subject 263, Trial 10
# Processed file: Subject 332, Trial 14
# Processed file: Subject 26, Trial 10
# Processed file: Subject 216, Trial 15
# Processed file: Subject 80, Trial 4
# Processed file: Subject 241, Trial 21
# Processed file: Subject 28, Trial 15
# Processed file: Subject 29, Trial 47
# Processed file: Subject 230, Trial 11
# Processed file: Subject 48, Trial 9
# Processed file: Subject 232, Trial 4
# Processed file: Subject 211, Trial 21
# Processed file: Subject 131, Trial 47
# Processed file: Subject 221, Trial 22
# Processed file: Subject 92, Trial 16
# Processed file: Subject 28, Trial 7
# Processed file: Subject 360, Trial 23
# Processed file: Subject 7, Trial 21
# Processed file: Subject 37, Trial 9
# Processed file: Subject 357, Trial 6
# Processed file: Subject 202, Trial 21
# Processed file: Subject 110, Trial 23
# Processed file: Subject 350, Trial 16
# Processed file: Subject 7, Trial 9
# Processed file: Subject 174, Trial 10
# Processed file: Subject 207, Trial 22
# Processed file: Subject 330, Trial 9
# Processed file: Subject 56, Trial 18
# Processed file: Subject 336, Trial 47
# Processed file: Subject 85, Trial 14
# Processed file: Subject 140, Trial 6
# Processed file: Subject 163, Trial 47
# Processed file: Subject 53, Trial 20
# Processed file: Subject 348, Trial 4
# Processed file: Subject 391, Trial 1
# Processed file: Subject 333, Trial 10
# Processed file: Subject 183, Trial 2
# Processed file: Subject 296, Trial 20
# Processed file: Subject 296, Trial 10
# Processed file: Subject 91, Trial 20
# Processed file: Subject 263, Trial 2
# Processed file: Subject 131, Trial 18
# Processed file: Subject 199, Trial 20
# Processed file: Subject 159, Trial 6
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S410_Q11.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 256, Trial 22
# Processed file: Subject 163, Trial 14
# Processed file: Subject 217, Trial 13
# Processed file: Subject 346, Trial 13
# Processed file: Subject 199, Trial 22
# Processed file: Subject 294, Trial 47
# Processed file: Subject 376, Trial 9
# Processed file: Subject 221, Trial 11
# Processed file: Subject 194, Trial 1
# Processed file: Subject 354, Trial 15
# Processed file: Subject 391, Trial 13
# Processed file: Subject 337, Trial 13
# Processed file: Subject 221, Trial 1
# Processed file: Subject 294, Trial 10
# Processed file: Subject 156, Trial 13
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S356_Q9.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 11, Trial 1
# Processed file: Subject 168, Trial 7
# Processed file: Subject 48, Trial 11
# Processed file: Subject 237, Trial 9
# Processed file: Subject 9, Trial 23
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S6_Q10.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 139, Trial 11
# Processed file: Subject 194, Trial 10
# Processed file: Subject 394, Trial 13
# Processed file: Subject 358, Trial 15
# Processed file: Subject 100, Trial 22
# Processed file: Subject 158, Trial 4
# Processed file: Subject 393, Trial 47
# Processed file: Subject 110, Trial 21
# Processed file: Subject 347, Trial 4
# Processed file: Subject 117, Trial 13
# Processed file: Subject 350, Trial 6
# Processed file: Subject 207, Trial 13
# Processed file: Subject 133, Trial 14
# Processed file: Subject 136, Trial 4
# Processed file: Subject 110, Trial 13
# Processed file: Subject 330, Trial 18
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S376_Q15.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 232, Trial 1
# Processed file: Subject 8, Trial 1
# Processed file: Subject 196, Trial 15
# Processed file: Subject 241, Trial 10
# Processed file: Subject 164, Trial 11
# Processed file: Subject 27, Trial 21
# Processed file: Subject 192, Trial 2
# Processed file: Subject 193, Trial 7
# Processed file: Subject 238, Trial 14
# Processed file: Subject 202, Trial 47
# Processed file: Subject 147, Trial 7
# Processed file: Subject 194, Trial 47
# Processed file: Subject 209, Trial 1
# Processed file: Subject 387, Trial 21
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S49_Q22.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 311, Trial 23
# Processed file: Subject 183, Trial 23
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S356_Q22.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 317, Trial 7
# Processed file: Subject 317, Trial 14
# Processed file: Subject 8, Trial 47
# Processed file: Subject 359, Trial 6
# Processed file: Subject 387, Trial 13
# Processed file: Subject 387, Trial 16
# Processed file: Subject 331, Trial 15
# Processed file: Subject 334, Trial 2
# Processed file: Subject 339, Trial 18
# Processed file: Subject 412, Trial 22
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S410_Q14.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 162, Trial 16
# Processed file: Subject 264, Trial 22
# Processed file: Subject 156, Trial 20
# Processed file: Subject 200, Trial 23
# Processed file: Subject 371, Trial 47
# Processed file: Subject 348, Trial 9
# Processed file: Subject 131, Trial 2
# Processed file: Subject 117, Trial 9
# Processed file: Subject 118, Trial 18
# Processed file: Subject 297, Trial 20
# Processed file: Subject 338, Trial 6
# Processed file: Subject 169, Trial 47
# Processed file: Subject 310, Trial 18
# Processed file: Subject 25, Trial 2
# Processed file: Subject 357, Trial 47
# Processed file: Subject 333, Trial 4
# Processed file: Subject 199, Trial 7
# Processed file: Subject 194, Trial 21
# Processed file: Subject 244, Trial 23
# Processed file: Subject 7, Trial 10
# Processed file: Subject 345, Trial 23
# Processed file: Subject 224, Trial 23
# Processed file: Subject 337, Trial 7
# Processed file: Subject 377, Trial 9
# Processed file: Subject 86, Trial 23
# Processed file: Subject 333, Trial 22
# Processed file: Subject 348, Trial 18
# Processed file: Subject 80, Trial 2
# Processed file: Subject 29, Trial 23
# Processed file: Subject 8, Trial 11
# Processed file: Subject 169, Trial 6
# Processed file: Subject 404, Trial 15
# Processed file: Subject 279, Trial 23
# Processed file: Subject 48, Trial 1
# Processed file: Subject 237, Trial 18
# Processed file: Subject 92, Trial 2
# Processed file: Subject 271, Trial 22
# Processed file: Subject 92, Trial 7
# Processed file: Subject 9, Trial 7
# Processed file: Subject 171, Trial 9
# Processed file: Subject 184, Trial 23
# Processed file: Subject 26, Trial 2
# Processed file: Subject 337, Trial 14
# Processed file: Subject 53, Trial 1
# Processed file: Subject 76, Trial 16
# Processed file: Subject 121, Trial 22
# Processed file: Subject 346, Trial 1
# Processed file: Subject 53, Trial 22
# Processed file: Subject 337, Trial 2
# Processed file: Subject 310, Trial 23
# Processed file: Subject 174, Trial 13
# Processed file: Subject 410, Trial 1
# Processed file: Subject 350, Trial 1
# Processed file: Subject 124, Trial 16
# Processed file: Subject 133, Trial 4
# Processed file: Subject 310, Trial 20
# Processed file: Subject 117, Trial 16
# Processed file: Subject 404, Trial 4
# Processed file: Subject 26, Trial 16
# Processed file: Subject 39, Trial 15
# Processed file: Subject 331, Trial 18
# Processed file: Subject 76, Trial 9
# Processed file: Subject 371, Trial 20
# Processed file: Subject 387, Trial 6
# Processed file: Subject 11, Trial 23
# Processed file: Subject 193, Trial 9
# Processed file: Subject 91, Trial 4
# Processed file: Subject 285, Trial 23
# Processed file: Subject 291, Trial 22
# Processed file: Subject 162, Trial 2
# Processed file: Subject 139, Trial 15
# Processed file: Subject 350, Trial 4
# Processed file: Subject 294, Trial 14
# Processed file: Subject 260, Trial 10
# Processed file: Subject 404, Trial 21
# Processed file: Subject 156, Trial 6
# Processed file: Subject 393, Trial 10
# Processed file: Subject 54, Trial 16
# Processed file: Subject 175, Trial 14
# Processed file: Subject 110, Trial 6
# Processed file: Subject 317, Trial 15
# Processed file: Subject 394, Trial 18
# Processed file: Subject 54, Trial 6
# Processed file: Subject 72, Trial 21
# Processed file: Subject 357, Trial 20
# Processed file: Subject 184, Trial 9
# Processed file: Subject 217, Trial 10
# Processed file: Subject 170, Trial 2
# Processed file: Subject 175, Trial 7
# Processed file: Subject 388, Trial 14
# Processed file: Subject 80, Trial 10
# Processed file: Subject 220, Trial 11
# Processed file: Subject 295, Trial 16
# Processed file: Subject 357, Trial 13
# Processed file: Subject 39, Trial 11
# Processed file: Subject 351, Trial 14
# Processed file: Subject 220, Trial 15
# Processed file: Subject 222, Trial 15
# Processed file: Subject 92, Trial 18
# Processed file: Subject 91, Trial 21
# Processed file: Subject 131, Trial 4
# Processed file: Subject 26, Trial 14
# Processed file: Subject 338, Trial 20
# Processed file: Subject 215, Trial 23
# Processed file: Subject 225, Trial 20
# Processed file: Subject 216, Trial 23
# Processed file: Subject 220, Trial 1
# Processed file: Subject 181, Trial 1
# Processed file: Subject 196, Trial 20
# Processed file: Subject 327, Trial 6
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S49_Q1.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 333, Trial 21
# Processed file: Subject 291, Trial 14
# Processed file: Subject 1, Trial 1
# Processed file: Subject 192, Trial 14
# Processed file: Subject 294, Trial 1
# Processed file: Subject 29, Trial 10
# Processed file: Subject 280, Trial 4
# Processed file: Subject 225, Trial 1
# Processed file: Subject 330, Trial 20
# Processed file: Subject 337, Trial 22
# Processed file: Subject 2, Trial 21
# Processed file: Subject 274, Trial 4
# Processed file: Subject 270, Trial 47
# Processed file: Subject 334, Trial 7
# Processed file: Subject 412, Trial 14
# Processed file: Subject 77, Trial 7
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S49_Q10.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 409, Trial 45
# Processed file: Subject 257, Trial 10
# Processed file: Subject 117, Trial 11
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S49_Q16.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 317, Trial 1
# Processed file: Subject 357, Trial 21
# Processed file: Subject 100, Trial 14
# Processed file: Subject 244, Trial 13
# Processed file: Subject 110, Trial 4
# Processed file: Subject 332, Trial 7
# Processed file: Subject 170, Trial 11
# Processed file: Subject 199, Trial 14
# Processed file: Subject 271, Trial 9
# Processed file: Subject 237, Trial 23
# Processed file: Subject 163, Trial 15
# Processed file: Subject 184, Trial 21
# Processed file: Subject 110, Trial 14
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S376_Q11.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 323, Trial 14
# Processed file: Subject 205, Trial 9
# Processed file: Subject 409, Trial 20
# Processed file: Subject 331, Trial 21
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S197_Q11.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 110, Trial 18
# Processed file: Subject 136, Trial 10
# Processed file: Subject 388, Trial 7
# Processed file: Subject 28, Trial 21
# Processed file: Subject 337, Trial 4
# Processed file: Subject 295, Trial 21
# Processed file: Subject 174, Trial 1
# Processed file: Subject 27, Trial 1
# Processed file: Subject 322, Trial 9
# Processed file: Subject 245, Trial 11
# Processed file: Subject 56, Trial 2
# Processed file: Subject 7, Trial 47
# Processed file: Subject 175, Trial 4
# Processed file: Subject 147, Trial 47
# Processed file: Subject 347, Trial 14
# Processed file: Subject 322, Trial 13
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S207_Q11.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 256, Trial 2
# Processed file: Subject 37, Trial 11
# Processed file: Subject 61, Trial 16
# Processed file: Subject 332, Trial 20
# Processed file: Subject 162, Trial 22
# Processed file: Subject 168, Trial 23
# Processed file: Subject 89, Trial 21
# Processed file: Subject 339, Trial 21
# Processed file: Subject 28, Trial 47
# Processed file: Subject 56, Trial 7
# Processed file: Subject 394, Trial 45
# Processed file: Subject 26, Trial 4
# Processed file: Subject 294, Trial 7
# Processed file: Subject 193, Trial 13
# Processed file: Subject 433, Trial 16
# Processed file: Subject 238, Trial 6
# Processed file: Subject 350, Trial 14
# Processed file: Subject 221, Trial 20
# Processed file: Subject 127, Trial 4
# Processed file: Subject 341, Trial 16
# Processed file: Subject 54, Trial 14
# Processed file: Subject 1, Trial 18
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S132_Q10.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 225, Trial 22
# Processed file: Subject 317, Trial 4
# Processed file: Subject 216, Trial 13
# Processed file: Subject 271, Trial 18
# Processed file: Subject 224, Trial 11
# Processed file: Subject 409, Trial 7
# Processed file: Subject 88, Trial 18
# Processed file: Subject 198, Trial 10
# Processed file: Subject 222, Trial 4
# Processed file: Subject 244, Trial 47
# Processed file: Subject 7, Trial 6
# Processed file: Subject 409, Trial 1
# Processed file: Subject 245, Trial 2
# Processed file: Subject 194, Trial 20
# Processed file: Subject 327, Trial 47
# Processed file: Subject 91, Trial 7
# Processed file: Subject 48, Trial 10
# Processed file: Subject 277, Trial 22
# Processed file: Subject 147, Trial 15
# Processed file: Subject 158, Trial 10
# Processed file: Subject 225, Trial 21
# Processed file: Subject 9, Trial 9
# Processed file: Subject 117, Trial 2
# Processed file: Subject 100, Trial 18
# Processed file: Subject 338, Trial 23
# Processed file: Subject 333, Trial 14
# Processed file: Subject 159, Trial 2
# Processed file: Subject 125, Trial 7
# Processed file: Subject 183, Trial 7
# Processed file: Subject 297, Trial 10
# Processed file: Subject 294, Trial 4
# Processed file: Subject 394, Trial 6
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S360_Q22.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 124, Trial 18
# Processed file: Subject 28, Trial 6
# Processed file: Subject 257, Trial 4
# Processed file: Subject 412, Trial 45
# Processed file: Subject 194, Trial 7
# Processed file: Subject 351, Trial 7
# Processed file: Subject 181, Trial 2
# Processed file: Subject 26, Trial 20
# Processed file: Subject 347, Trial 18
# Processed file: Subject 200, Trial 18
# Processed file: Subject 297, Trial 22
# Processed file: Subject 56, Trial 10
# Processed file: Subject 76, Trial 4
# Processed file: Subject 80, Trial 18
# Processed file: Subject 346, Trial 9
# Processed file: Subject 175, Trial 23
# Processed file: Subject 217, Trial 7
# Processed file: Subject 169, Trial 1
# Processed file: Subject 184, Trial 6
# Processed file: Subject 330, Trial 47
# Processed file: Subject 231, Trial 47
# Processed file: Subject 241, Trial 16
# Processed file: Subject 86, Trial 22
# Processed file: Subject 133, Trial 13
# Processed file: Subject 294, Trial 23
# Processed file: Subject 44, Trial 13
# Processed file: Subject 388, Trial 47
# Processed file: Subject 168, Trial 15
# Processed file: Subject 336, Trial 7
# Processed file: Subject 54, Trial 22
# Processed file: Subject 336, Trial 15
# Processed file: Subject 322, Trial 23
# Processed file: Subject 393, Trial 6
# Processed file: Subject 391, Trial 16
# Processed file: Subject 175, Trial 21
# Processed file: Subject 118, Trial 6
# Processed file: Subject 88, Trial 23
# Processed file: Subject 119, Trial 22
# Processed file: Subject 12, Trial 20
# Processed file: Subject 183, Trial 47
# Processed file: Subject 91, Trial 13
# Processed file: Subject 8, Trial 23
# Processed file: Subject 197, Trial 14
# Processed file: Subject 412, Trial 23
# Processed file: Subject 2, Trial 11
# Processed file: Subject 127, Trial 23
# Processed file: Subject 338, Trial 10
# Processed file: Subject 86, Trial 20
# Processed file: Subject 133, Trial 7
# Processed file: Subject 7, Trial 1
# Processed file: Subject 332, Trial 23
# Processed file: Subject 9, Trial 4
# Processed file: Subject 25, Trial 9
# Processed file: Subject 181, Trial 9
# Processed file: Subject 389, Trial 18
# Processed file: Subject 2, Trial 16
# Processed file: Subject 221, Trial 14
# Processed file: Subject 111, Trial 47
# Processed file: Subject 345, Trial 21
# Processed file: Subject 412, Trial 11
# Processed file: Subject 271, Trial 10
# Processed file: Subject 433, Trial 13
# Processed file: Subject 327, Trial 18
# Processed file: Subject 133, Trial 10
# Processed file: Subject 207, Trial 23
# Processed file: Subject 168, Trial 22
# Processed file: Subject 238, Trial 16
# Processed file: Subject 125, Trial 15
# Processed file: Subject 163, Trial 18
# Processed file: Subject 388, Trial 22
# Processed file: Subject 91, Trial 47
# Processed file: Subject 241, Trial 20
# Processed file: Subject 347, Trial 10
# Processed file: Subject 224, Trial 7
# Processed file: Subject 163, Trial 2
# Processed file: Subject 119, Trial 10
# Processed file: Subject 158, Trial 21
# Processed file: Subject 207, Trial 21
# Processed file: Subject 331, Trial 23
# Processed file: Subject 358, Trial 10
# Processed file: Subject 207, Trial 16
# Processed file: Subject 394, Trial 1
# Processed file: Subject 237, Trial 6
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S49_Q20.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 341, Trial 20
# Processed file: Subject 196, Trial 16
# Processed file: Subject 48, Trial 13
# Processed file: Subject 119, Trial 13
# Processed file: Subject 158, Trial 16
# Processed file: Subject 204, Trial 4
# Processed file: Subject 80, Trial 21
# Processed file: Subject 140, Trial 10
# Processed file: Subject 296, Trial 4
# Processed file: Subject 39, Trial 21
# Processed file: Subject 376, Trial 2
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S413_Q13.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 157, Trial 47
# Processed file: Subject 147, Trial 11
# Processed file: Subject 216, Trial 11
# Processed file: Subject 293, Trial 15
# Processed file: Subject 199, Trial 9
# Processed file: Subject 317, Trial 47
# Processed file: Subject 354, Trial 23
# Processed file: Subject 349, Trial 13
# Processed file: Subject 274, Trial 47
# Processed file: Subject 297, Trial 18
# Processed file: Subject 222, Trial 47
# Processed file: Subject 144, Trial 4
# Processed file: Subject 284, Trial 23
# Processed file: Subject 166, Trial 10
# Processed file: Subject 122, Trial 10
# Processed file: Subject 331, Trial 9
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S117_Q23.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 198, Trial 18
# Processed file: Subject 388, Trial 20
# Processed file: Subject 285, Trial 9
# Processed file: Subject 334, Trial 18
# Processed file: Subject 121, Trial 7
# Processed file: Subject 293, Trial 6
# Processed file: Subject 53, Trial 18
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S413_Q23.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 198, Trial 14
# Processed file: Subject 38, Trial 4
# Processed file: Subject 205, Trial 11
# Processed file: Subject 61, Trial 18
# Processed file: Subject 393, Trial 23
# Processed file: Subject 181, Trial 4
# Processed file: Subject 28, Trial 2
# Processed file: Subject 388, Trial 11
# Processed file: Subject 217, Trial 9
# Processed file: Subject 11, Trial 21
# Processed file: Subject 310, Trial 6
# Processed file: Subject 339, Trial 16
# Processed file: Subject 171, Trial 11
# Processed file: Subject 322, Trial 21
# Processed file: Subject 136, Trial 11
# Processed file: Subject 184, Trial 10
# Processed file: Subject 9, Trial 6
# Processed file: Subject 388, Trial 15
# Processed file: Subject 131, Trial 16
# Processed file: Subject 327, Trial 10
# Processed file: Subject 323, Trial 16
# Processed file: Subject 76, Trial 10
# Processed file: Subject 11, Trial 16
# Processed file: Subject 297, Trial 23
# Processed file: Subject 204, Trial 2
# Processed file: Subject 345, Trial 14
# Processed file: Subject 44, Trial 16
# Processed file: Subject 296, Trial 14
# Processed file: Subject 165, Trial 20
# Processed file: Subject 194, Trial 23
# Processed file: Subject 127, Trial 22
# Processed file: Subject 12, Trial 4
# Processed file: Subject 162, Trial 7
# Processed file: Subject 220, Trial 10
# Processed file: Subject 80, Trial 15
# Processed file: Subject 237, Trial 21
# Processed file: Subject 164, Trial 10
# Processed file: Subject 110, Trial 2
# Processed file: Subject 136, Trial 23
# Processed file: Subject 156, Trial 1
# Processed file: Subject 404, Trial 20
# Processed file: Subject 204, Trial 10
# Processed file: Subject 171, Trial 21
# Processed file: Subject 391, Trial 4
# Processed file: Subject 156, Trial 18
# Processed file: Subject 156, Trial 4
# Processed file: Subject 89, Trial 16
# Processed file: Subject 339, Trial 14
# Processed file: Subject 61, Trial 4
# Processed file: Subject 230, Trial 2
# Processed file: Subject 326, Trial 20
# Processed file: Subject 54, Trial 11
# Processed file: Subject 245, Trial 23
# Processed file: Subject 165, Trial 15
# Processed file: Subject 8, Trial 10
# Processed file: Subject 12, Trial 11
# Processed file: Subject 166, Trial 14
# Processed file: Subject 260, Trial 1
# Processed file: Subject 216, Trial 16
# Processed file: Subject 326, Trial 22
# Processed file: Subject 217, Trial 18
# Processed file: Subject 338, Trial 21
# Processed file: Subject 217, Trial 4
# Processed file: Subject 39, Trial 16
# Processed file: Subject 216, Trial 7
# Processed file: Subject 229, Trial 18
# Processed file: Subject 354, Trial 13
# Processed file: Subject 122, Trial 2
# Processed file: Subject 358, Trial 22
# Processed file: Subject 165, Trial 16
# Processed file: Subject 100, Trial 1
# Processed file: Subject 166, Trial 4
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S72_Q10.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 297, Trial 11
# Processed file: Subject 311, Trial 11
# Processed file: Subject 29, Trial 21
# Processed file: Subject 337, Trial 16
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S207_Q6.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 404, Trial 22
# Processed file: Subject 330, Trial 11
# Processed file: Subject 295, Trial 14
# Processed file: Subject 133, Trial 1
# Processed file: Subject 124, Trial 22
# Processed file: Subject 144, Trial 22
# Processed file: Subject 222, Trial 7
# Processed file: Subject 1, Trial 16
# Processed file: Subject 198, Trial 13
# Processed file: Subject 169, Trial 7
# Processed file: Subject 296, Trial 23
# Processed file: Subject 162, Trial 13
# Processed file: Subject 131, Trial 15
# Processed file: Subject 346, Trial 6
# Processed file: Subject 391, Trial 22
# Processed file: Subject 29, Trial 16
# Processed file: Subject 260, Trial 15
# Processed file: Subject 224, Trial 10
# Processed file: Subject 92, Trial 4
# Processed file: Subject 389, Trial 20
# Processed file: Subject 274, Trial 7
# Processed file: Subject 183, Trial 13
# Processed file: Subject 346, Trial 14
# Processed file: Subject 171, Trial 18
# Processed file: Subject 404, Trial 11
# Processed file: Subject 166, Trial 20
# Processed file: Subject 311, Trial 15
# Processed file: Subject 338, Trial 14
# Processed file: Subject 184, Trial 14
# Processed file: Subject 297, Trial 16
# Processed file: Subject 412, Trial 1
# Processed file: Subject 125, Trial 11
# Processed file: Subject 409, Trial 2
# Processed file: Subject 156, Trial 21
# Processed file: Subject 85, Trial 15
# Processed file: Subject 136, Trial 22
# Processed file: Subject 86, Trial 15
# Processed file: Subject 246, Trial 18
# Processed file: Subject 245, Trial 13
# Processed file: Subject 215, Trial 15
# Processed file: Subject 100, Trial 9
# Processed file: Subject 111, Trial 4
# Processed file: Subject 38, Trial 21
# Processed file: Subject 348, Trial 16
# Processed file: Subject 44, Trial 4
# Processed file: Subject 163, Trial 6
# Processed file: Subject 260, Trial 6
# Processed file: Subject 361, Trial 23
# Processed file: Subject 48, Trial 22
# Processed file: Subject 389, Trial 16
# Processed file: Subject 278, Trial 4
# Processed file: Subject 127, Trial 2
# Processed file: Subject 296, Trial 47
# Processed file: Subject 163, Trial 20
# Processed file: Subject 38, Trial 18
# Processed file: Subject 260, Trial 18
# Processed file: Subject 193, Trial 10
# Processed file: Subject 144, Trial 2
# Processed file: Subject 100, Trial 2
# Processed file: Subject 263, Trial 20
# Processed file: Subject 138, Trial 16
# Processed file: Subject 389, Trial 23
# Processed file: Subject 334, Trial 23
# Processed file: Subject 338, Trial 1
# Processed file: Subject 80, Trial 47
# Processed file: Subject 197, Trial 4
# Processed file: Subject 165, Trial 6
# Processed file: Subject 229, Trial 23
# Processed file: Subject 284, Trial 9
# Processed file: Subject 54, Trial 23
# Processed file: Subject 136, Trial 6
# Processed file: Subject 224, Trial 15
# Processed file: Subject 256, Trial 4
# Processed file: Subject 28, Trial 1
# Processed file: Subject 11, Trial 47
# Processed file: Subject 311, Trial 4
# Processed file: Subject 192, Trial 21
# Processed file: Subject 222, Trial 13
# Processed file: Subject 138, Trial 9
# Processed file: Subject 163, Trial 9
# Processed file: Subject 39, Trial 18
# Processed file: Subject 277, Trial 9
# Processed file: Subject 317, Trial 10
# Processed file: Subject 86, Trial 16
# Processed file: Subject 322, Trial 4
# Processed file: Subject 38, Trial 2
# Processed file: Subject 229, Trial 7
# Processed file: Subject 231, Trial 18
# Processed file: Subject 293, Trial 2
# Processed file: Subject 207, Trial 9
# Processed file: Subject 222, Trial 20
# Processed file: Subject 76, Trial 21
# Processed file: Subject 166, Trial 18
# Processed file: Subject 389, Trial 6
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S196_Q9.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 351, Trial 10
# Processed file: Subject 351, Trial 47
# Processed file: Subject 413, Trial 45
# Processed file: Subject 193, Trial 23
# Processed file: Subject 202, Trial 18
# Processed file: Subject 39, Trial 23
# Processed file: Subject 166, Trial 9
# Processed file: Subject 225, Trial 9
# Processed file: Subject 257, Trial 20
# Processed file: Subject 202, Trial 15
# Processed file: Subject 263, Trial 22
# Processed file: Subject 244, Trial 1
# Processed file: Subject 229, Trial 10
# Processed file: Subject 241, Trial 13
# Processed file: Subject 323, Trial 1
# Processed file: Subject 200, Trial 6
# Processed file: Subject 336, Trial 20
# Processed file: Subject 323, Trial 2
# Processed file: Subject 257, Trial 14
# Processed file: Subject 357, Trial 18
# Processed file: Subject 346, Trial 10
# Processed file: Subject 348, Trial 47
# Processed file: Subject 322, Trial 10
# Processed file: Subject 339, Trial 6
# Processed file: Subject 284, Trial 11
# Processed file: Subject 38, Trial 20
# Processed file: Subject 171, Trial 2
# Processed file: Subject 111, Trial 22
# Processed file: Subject 285, Trial 7
# Processed file: Subject 192, Trial 1
# Processed file: Subject 331, Trial 20
# Processed file: Subject 277, Trial 11
# Processed file: Subject 131, Trial 22
# Processed file: Subject 270, Trial 9
# Processed file: Subject 327, Trial 13
# Processed file: Subject 413, Trial 9
# Processed file: Subject 389, Trial 45
# Processed file: Subject 171, Trial 47
# Processed file: Subject 330, Trial 2
# Processed file: Subject 246, Trial 11
# Processed file: Subject 394, Trial 4
# Processed file: Subject 393, Trial 15
# Processed file: Subject 387, Trial 10
# Processed file: Subject 245, Trial 6
# Processed file: Subject 377, Trial 23
# Processed file: Subject 225, Trial 11
# Processed file: Subject 284, Trial 13
# Processed file: Subject 345, Trial 6
# Processed file: Subject 285, Trial 18
# Processed file: Subject 28, Trial 9
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S198_Q20.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 138, Trial 47
# Processed file: Subject 209, Trial 7
# Processed file: Subject 100, Trial 13
# Processed file: Subject 237, Trial 10
# Processed file: Subject 27, Trial 13
# Processed file: Subject 163, Trial 10
# Processed file: Subject 241, Trial 2
# Processed file: Subject 207, Trial 2
# Processed file: Subject 202, Trial 23
# Processed file: Subject 358, Trial 4
# Processed file: Subject 284, Trial 7
# Processed file: Subject 334, Trial 15
# Processed file: Subject 8, Trial 6
# Processed file: Subject 280, Trial 10
# Processed file: Subject 322, Trial 22
# Processed file: Subject 28, Trial 10
# Processed file: Subject 391, Trial 14
# Processed file: Subject 127, Trial 21
# Processed file: Subject 285, Trial 2
# Processed file: Subject 159, Trial 23
# Processed file: Subject 193, Trial 2
# Processed file: Subject 48, Trial 15
# Processed file: Subject 138, Trial 2
# Processed file: Subject 48, Trial 2
# Processed file: Subject 158, Trial 9
# Processed file: Subject 28, Trial 22
# Processed file: Subject 279, Trial 22
# Processed file: Subject 49, Trial 9
# Processed file: Subject 88, Trial 4
# Processed file: Subject 139, Trial 10
# Processed file: Subject 225, Trial 10
# Processed file: Subject 291, Trial 20
# Processed file: Subject 25, Trial 20
# Processed file: Subject 332, Trial 1
# Processed file: Subject 376, Trial 21
# Processed file: Subject 139, Trial 6
# Processed file: Subject 91, Trial 2
# Processed file: Subject 231, Trial 16
# Processed file: Subject 322, Trial 47
# Processed file: Subject 317, Trial 20
# Processed file: Subject 387, Trial 4
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S49_Q7.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 338, Trial 18
# Processed file: Subject 271, Trial 15
# Processed file: Subject 29, Trial 1
# Processed file: Subject 139, Trial 2
# Processed file: Subject 136, Trial 9
# Processed file: Subject 221, Trial 6
# Processed file: Subject 162, Trial 47
# Processed file: Subject 85, Trial 22
# Processed file: Subject 295, Trial 7
# Processed file: Subject 317, Trial 22
# Processed file: Subject 181, Trial 10
# Processed file: Subject 331, Trial 22
# Processed file: Subject 119, Trial 47
# Processed file: Subject 30, Trial 23
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S132_Q7.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 56, Trial 9
# Processed file: Subject 200, Trial 16
# Processed file: Subject 391, Trial 9
# Processed file: Subject 220, Trial 20
# Processed file: Subject 211, Trial 2
# Processed file: Subject 215, Trial 2
# Processed file: Subject 157, Trial 18
# Processed file: Subject 291, Trial 4
# Processed file: Subject 284, Trial 2
# Processed file: Subject 246, Trial 47
# Processed file: Subject 202, Trial 16
# Processed file: Subject 270, Trial 16
# Processed file: Subject 257, Trial 11
# Processed file: Subject 229, Trial 16
# Processed file: Subject 231, Trial 11
# Processed file: Subject 238, Trial 1
# Processed file: Subject 317, Trial 18
# Processed file: Subject 376, Trial 22
# ...
# Error processing file S244_Q9.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 122, Trial 13
# Processed file: Subject 317, Trial 9
# Processed file: Subject 297, Trial 15
# Processed file: Subject 413, Trial 6
# Processed file: Subject 277, Trial 21
# Processed file: Subject 241, Trial 15
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S2_Q15.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 171, Trial 10
# Processed file: Subject 222, Trial 10
# Processed file: Subject 409, Trial 10
# Processed file: Subject 348, Trial 1
# Processed file: Subject 162, Trial 9
# Processed file: Subject 58, Trial 4
# Processed file: Subject 170, Trial 21
# Processed file: Subject 246, Trial 23
# Processed file: Subject 222, Trial 23
# Processed file: Subject 86, Trial 9
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S410_Q21.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 334, Trial 21
# Processed file: Subject 349, Trial 11
# Processed file: Subject 220, Trial 21
# Processed file: Subject 202, Trial 2
# Processed file: Subject 8, Trial 7
# Processed file: Subject 404, Trial 18
# Processed file: Subject 232, Trial 15
# Processed file: Subject 358, Trial 23
# Processed file: Subject 345, Trial 11
# Processed file: Subject 293, Trial 14
# Processed file: Subject 44, Trial 1
# Processed file: Subject 164, Trial 47
# Processed file: Subject 86, Trial 47
# Processed file: Subject 56, Trial 47
# Processed file: Subject 216, Trial 47
# Processed file: Subject 296, Trial 2
# Processed file: Subject 361, Trial 15
# Processed file: Subject 169, Trial 15
# Processed file: Subject 168, Trial 18
# Processed file: Subject 139, Trial 16
# Processed file: Subject 311, Trial 7
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S49_Q15.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 147, Trial 4
# Processed file: Subject 294, Trial 21
# Processed file: Subject 165, Trial 1
# Processed file: Subject 284, Trial 47
# Processed file: Subject 291, Trial 23
# Processed file: Subject 194, Trial 16
# Processed file: Subject 341, Trial 23
# Processed file: Subject 76, Trial 2
# Processed file: Subject 433, Trial 7
# Processed file: Subject 327, Trial 20
# Processed file: Subject 76, Trial 7
# Processed file: Subject 284, Trial 4
# Processed file: Subject 110, Trial 20
# Processed file: Subject 297, Trial 4
# Processed file: Subject 88, Trial 11
# Processed file: Subject 122, Trial 22
# Processed file: Subject 230, Trial 18
# Processed file: Subject 204, Trial 16
# Processed file: Subject 44, Trial 22
# Processed file: Subject 349, Trial 6
# Processed file: Subject 361, Trial 47
# Processed file: Subject 277, Trial 6
# Processed file: Subject 184, Trial 1
# Processed file: Subject 231, Trial 9
# Processed file: Subject 200, Trial 11
# Processed file: Subject 360, Trial 6
# Processed file: Subject 89, Trial 13
# Processed file: Subject 127, Trial 11
# Processed file: Subject 215, Trial 22
# Processed file: Subject 347, Trial 2
# Processed file: Subject 174, Trial 4
# Processed file: Subject 56, Trial 11
# Processed file: Subject 202, Trial 20
# Processed file: Subject 278, Trial 2
# Processed file: Subject 351, Trial 4
# Processed file: Subject 139, Trial 1
# Processed file: Subject 168, Trial 47
# Processed file: Subject 8, Trial 2
# Processed file: Subject 222, Trial 16
# Processed file: Subject 144, Trial 9
# Processed file: Subject 271, Trial 1
# Processed file: Subject 125, Trial 6
# Processed file: Subject 237, Trial 16
# Processed file: Subject 330, Trial 13
# Processed file: Subject 169, Trial 22
# Processed file: Subject 409, Trial 6
# Processed file: Subject 159, Trial 14
# Processed file: Subject 171, Trial 22
# Processed file: Subject 338, Trial 22
# Processed file: Subject 263, Trial 23
# Processed file: Subject 57, Trial 6
# Processed file: Subject 133, Trial 47
# Processed file: Subject 237, Trial 47
# Processed file: Subject 138, Trial 10
# Processed file: Subject 285, Trial 10
# Processed file: Subject 92, Trial 22
# Processed file: Subject 295, Trial 18
# Processed file: Subject 215, Trial 18
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S72_Q15.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 139, Trial 47
# Processed file: Subject 221, Trial 18
# Processed file: Subject 25, Trial 22
# Processed file: Subject 88, Trial 20
# Processed file: Subject 332, Trial 16
# Processed file: Subject 257, Trial 21
# Processed file: Subject 332, Trial 15
# Processed file: Subject 350, Trial 47
# Processed file: Subject 245, Trial 4
# Processed file: Subject 351, Trial 23
# Processed file: Subject 39, Trial 22
# Processed file: Subject 196, Trial 14
# Processed file: Subject 284, Trial 18
# Processed file: Subject 264, Trial 2
# Processed file: Subject 192, Trial 4
# Processed file: Subject 349, Trial 22
# Processed file: Subject 168, Trial 2
# Processed file: Subject 231, Trial 1
# Processed file: Subject 388, Trial 4
# Processed file: Subject 326, Trial 18
# Processed file: Subject 184, Trial 18
# Processed file: Subject 184, Trial 22
# Processed file: Subject 197, Trial 47
# Processed file: Subject 85, Trial 47
# Processed file: Subject 391, Trial 6
# Processed file: Subject 270, Trial 20
# Processed file: Subject 295, Trial 20
# Processed file: Subject 433, Trial 18
# Processed file: Subject 206, Trial 6
# Processed file: Subject 371, Trial 2
# Processed file: Subject 277, Trial 4
# Processed file: Subject 311, Trial 18
# Processed file: Subject 237, Trial 11
# Processed file: Subject 171, Trial 15
# Processed file: Subject 53, Trial 47
# Processed file: Subject 206, Trial 22
# Processed file: Subject 147, Trial 14
# Processed file: Subject 221, Trial 15
# Processed file: Subject 221, Trial 7
# Processed file: Subject 170, Trial 4
# Processed file: Subject 122, Trial 21
# Processed file: Subject 138, Trial 15
# Processed file: Subject 25, Trial 1
# Processed file: Subject 256, Trial 7
# Processed file: Subject 274, Trial 13
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S196_Q47.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 310, Trial 14
# Processed file: Subject 88, Trial 1
# Processed file: Subject 175, Trial 1
# Processed file: Subject 133, Trial 9
# Processed file: Subject 38, Trial 7
# Processed file: Subject 371, Trial 10
# Processed file: Subject 260, Trial 16
# Processed file: Subject 389, Trial 9
# Processed file: Subject 354, Trial 11
# Processed file: Subject 86, Trial 6
# Processed file: Subject 231, Trial 22
# Processed file: Subject 245, Trial 22
# Processed file: Subject 376, Trial 1
# Processed file: Subject 48, Trial 4
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S404_Q45.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 260, Trial 4
# Processed file: Subject 257, Trial 9
# Processed file: Subject 337, Trial 1
# Processed file: Subject 110, Trial 22
# Processed file: Subject 57, Trial 20
# Processed file: Subject 209, Trial 21
# Processed file: Subject 391, Trial 47
# Processed file: Subject 88, Trial 7
# Processed file: Subject 345, Trial 7
# Processed file: Subject 295, Trial 22
# Processed file: Subject 111, Trial 1
# Processed file: Subject 338, Trial 4
# Processed file: Subject 331, Trial 47
# Processed file: Subject 138, Trial 22
# Processed file: Subject 184, Trial 2
# Processed file: Subject 159, Trial 18
# Processed file: Subject 169, Trial 16
# Processed file: Subject 230, Trial 22
# Processed file: Subject 117, Trial 4
# Processed file: Subject 404, Trial 1
# Processed file: Subject 345, Trial 16
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S72_Q13.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 144, Trial 11
# Processed file: Subject 28, Trial 14
# Processed file: Subject 293, Trial 18
# Processed file: Subject 57, Trial 23
# Processed file: Subject 88, Trial 2
# Processed file: Subject 38, Trial 13
# Processed file: Subject 310, Trial 15
# Processed file: Subject 323, Trial 18
# Processed file: Subject 204, Trial 6
# Processed file: Subject 165, Trial 18
# Processed file: Subject 349, Trial 10
# Processed file: Subject 410, Trial 2
# Processed file: Subject 206, Trial 9
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S376_Q10.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 348, Trial 10
# Processed file: Subject 263, Trial 15
# Processed file: Subject 294, Trial 15
# Processed file: Subject 237, Trial 13
# Processed file: Subject 27, Trial 18
# Processed file: Subject 327, Trial 23
# Processed file: Subject 409, Trial 16
# Processed file: Subject 86, Trial 21
# Processed file: Subject 222, Trial 1
# Processed file: Subject 237, Trial 22
# Processed file: Subject 371, Trial 1
# Processed file: Subject 25, Trial 7
# Processed file: Subject 257, Trial 23
# Processed file: Subject 350, Trial 11
# Processed file: Subject 209, Trial 4
# Processed file: Subject 327, Trial 2
# Processed file: Subject 48, Trial 16
# Processed file: Subject 274, Trial 15
# Processed file: Subject 8, Trial 22
# Processed file: Subject 156, Trial 9
# Processed file: Subject 326, Trial 2
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S360_Q18.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 326, Trial 23
# Processed file: Subject 257, Trial 15
# Processed file: Subject 168, Trial 20
# Processed file: Subject 394, Trial 16
# Processed file: Subject 391, Trial 11
# Processed file: Subject 294, Trial 13
# Processed file: Subject 271, Trial 20
# Processed file: Subject 330, Trial 16
# Processed file: Subject 357, Trial 23
# Processed file: Subject 206, Trial 10
# Processed file: Subject 121, Trial 20
# Processed file: Subject 57, Trial 14
# Processed file: Subject 334, Trial 22
# Processed file: Subject 339, Trial 7
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S199_Q10.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 157, Trial 22
# Processed file: Subject 295, Trial 11
# Processed file: Subject 164, Trial 6
# Processed file: Subject 349, Trial 18
# Processed file: Subject 44, Trial 20
# Processed file: Subject 132, Trial 9
# Processed file: Subject 183, Trial 15
# Processed file: Subject 171, Trial 14
# Processed file: Subject 85, Trial 18
# Processed file: Subject 110, Trial 47
# Processed file: Subject 412, Trial 20
# Processed file: Subject 412, Trial 15
# Processed file: Subject 277, Trial 7
# Processed file: Subject 88, Trial 22
# Processed file: Subject 277, Trial 23
# Processed file: Subject 1, Trial 4
# Processed file: Subject 333, Trial 23
# Processed file: Subject 202, Trial 1
# Processed file: Subject 337, Trial 9
# Processed file: Subject 159, Trial 7
# Processed file: Subject 202, Trial 7
# Processed file: Subject 238, Trial 20
# Processed file: Subject 232, Trial 6
# Processed file: Subject 144, Trial 13
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S49_Q4.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 138, Trial 4
# Processed file: Subject 387, Trial 22
# Processed file: Subject 28, Trial 20
# Processed file: Subject 413, Trial 18
# Processed file: Subject 121, Trial 6
# Processed file: Subject 326, Trial 9
# Processed file: Subject 2, Trial 14
# Processed file: Subject 202, Trial 11
# Processed file: Subject 339, Trial 13
# Processed file: Subject 229, Trial 13
# Processed file: Subject 310, Trial 2
# Processed file: Subject 220, Trial 18
# Processed file: Subject 200, Trial 2
# Processed file: Subject 171, Trial 1
# Processed file: Subject 334, Trial 1
# Processed file: Subject 413, Trial 21
# Processed file: Subject 331, Trial 14
# Processed file: Subject 12, Trial 18
# Processed file: Subject 270, Trial 23
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S207_Q4.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 391, Trial 20
# Processed file: Subject 216, Trial 18
# Processed file: Subject 413, Trial 2
# Processed file: Subject 337, Trial 47
# Processed file: Subject 341, Trial 1
# Processed file: Subject 202, Trial 22
# Processed file: Subject 274, Trial 21
# Processed file: Subject 163, Trial 21
# Processed file: Subject 293, Trial 7
# Processed file: Subject 168, Trial 16
# Processed file: Subject 238, Trial 22
# Processed file: Subject 410, Trial 7
# Processed file: Subject 27, Trial 16
# Processed file: Subject 231, Trial 21
# Processed file: Subject 354, Trial 7
# Processed file: Subject 56, Trial 13
# Processed file: Subject 332, Trial 4
# Processed file: Subject 199, Trial 23
# Processed file: Subject 86, Trial 10
# Warning: Skipping because non-meaningful silhouette score
# Error processing file S72_Q9.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 158, Trial 20
# Processed file: Subject 404, Trial 16
# Processed file: Subject 37, Trial 7
# Processed file: Subject 409, Trial 14
# Processed file: Subject 311, Trial 2
# Processed file: Subject 168, Trial 4
# Processed file: Subject 387, Trial 18
# Processed file: Subject 138, Trial 6
# Processed file: Subject 119, Trial 11
# Processed file: Subject 124, Trial 7
# Processed file: Subject 293, Trial 1
# Processed file: Subject 26, Trial 11
# Processed file: Subject 76, Trial 22
# Processed file: Subject 164, Trial 2
# Processed file: Subject 409, Trial 15
# Processed file: Subject 354, Trial 16
# Processed file: Subject 350, Trial 21
# Processed file: Subject 193, Trial 22
# Processed file: Subject 334, Trial 10
# Processed file: Subject 1, Trial 13
# Processed file: Subject 197, Trial 6
# Processed file: Subject 357, Trial 14
# Processed file: Subject 230, Trial 47
# Processed file: Subject 257, Trial 47
# Processed file: Subject 389, Trial 22
# Processed file: Subject 198, Trial 47
# Processed file: Subject 169, Trial 21
# Processed file: Subject 285, Trial 11
# Processed file: Subject 169, Trial 14
# Processed file: Subject 341, Trial 15
# Processed file: Subject 389, Trial 11
# Processed file: Subject 7, Trial 15
# Processed file: Subject 2, Trial 13
# Processed file: Subject 310, Trial 10
# Processed file: Subject 221, Trial 9
# Processed file: Subject 357, Trial 9
# Processed file: Subject 157, Trial 14
# Processed file: Subject 91, Trial 18
# Processed file: Subject 394, Trial 9
# Processed file: Subject 270, Trial 18
# Processed file: Subject 57, Trial 11
# Processed file: Subject 284, Trial 1
# Processed file: Subject 274, Trial 2
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S196_Q23.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 277, Trial 14
# Processed file: Subject 12, Trial 13
# Processed file: Subject 238, Trial 9
# Processed file: Subject 144, Trial 6
# Processed file: Subject 54, Trial 47
# Processed file: Subject 349, Trial 47
# Processed file: Subject 291, Trial 18
# Processed file: Subject 119, Trial 20
# Processed file: Subject 127, Trial 7
# Processed file: Subject 351, Trial 2
# Processed file: Subject 256, Trial 18
# Processed file: Subject 280, Trial 13
# Processed file: Subject 217, Trial 11
# Processed file: Subject 88, Trial 15
# Processed file: Subject 274, Trial 14
# Processed file: Subject 412, Trial 47
# Processed file: Subject 232, Trial 14
# Processed file: Subject 193, Trial 15
# Processed file: Subject 209, Trial 6
# Processed file: Subject 224, Trial 2
# Processed file: Subject 27, Trial 4
# Processed file: Subject 211, Trial 20
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S6_Q9.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 433, Trial 2
# Processed file: Subject 270, Trial 7
# Processed file: Subject 136, Trial 2
# Warning: Not enough data for clustering (len(df) < 2)
# Error processing file S49_Q11.csv: 'NoneType' object has no attribute 'to_csv'
# Processed file: Subject 291, Trial 9
# Processed file: Subject 156, Trial 14
# Processed file: Subject 229, Trial 2
# Processed file: Subject 371, Trial 21
# Processed file: Subject 322, Trial 2
# Processed file: Subject 330, Trial 21
# Processed file: Subject 157, Trial 9
# Processed file: Subject 336, Trial 22
# Processed file: Subject 54, Trial 10
# Processed file: Subject 394, Trial 47
# Processed file: Subject 174, Trial 16
# Processed file: Subject 8, Trial 13
# Processed file: Subject 295, Trial 1

# %%
# Percorsi delle cartelle
folder_csv_post = "ResidualProducts/csvPostX-Y_RangeCleaning"
folder_fixations = "ResidualProducts/Fixations-PreProcessing"

# Lista per memorizzare i risultati
data = []

# Itera attraverso i file nella cartella csvPostX-Y_RangeCleaning
for filename in os.listdir(folder_csv_post):
    if filename.endswith(".csv"):
        # Costruisci i percorsi completi
        path_csv = os.path.join(folder_csv_post, filename)
        path_fixation = os.path.join(folder_fixations, filename)

        # Verifica che il file corrispondente esista nella cartella Fixations
        if os.path.exists(path_fixation):
            # Carica i file CSV
            df_csv = pd.read_csv(path_csv)
            df_fixation = pd.read_csv(path_fixation)

            # Calcola FixationDurCumulated come somma della colonna 'duration'
            fixation_dur_cumulated = df_fixation['duration'].sum()

            # Calcola Duration come numero di righe del file csvPostRange * 77
            duration = len(df_csv) * 77

            # Aggiungi i dati alla lista
            data.append({
                'File': filename,
                'FixationDurCumulated': fixation_dur_cumulated,
                'Duration': duration
            })

# Creazione del DataFrame finale
results_df = pd.DataFrame(data)

results_df['Score'] = results_df['FixationDurCumulated'] / results_df['Duration']

# %%
# Sort the DataFrame by the number of rows in ascending order
results_df = results_df.sort_values(by="Score").reset_index(drop=True)

# Save the DataFrame to a CSV file (optional)
results_df.to_csv("ResidualProducts/file_row_counts.csv", index=False)

# Plot 1: Ascending number of rows
plt.figure(figsize=(10, 6))
plt.plot(range(len(results_df)), results_df["Score"], marker='.', alpha=0.7)

length = len(results_df)
dur_5 = int(length * 0.05)  # Calculate the index corresponding to the 5th percentile of the data

el = results_df.head(dur_5)

eliminated = pd.concat([eliminated, el['File']])
eliminated

# Find the y-value (number of fixations) at the 5th percentile index
y_5th = results_df['Score'].iloc[dur_5]

# Draw a vertical line at the 5th percentile to indicate its position
plt.axvline(x=dur_5, color='red', linestyle='--', label='5th-Percentile')

# Draw thin black horizontal lines at the y-value of the 5th percentile
plt.axhline(y=y_5th, color='black', linestyle='-', linewidth=0.7)


plt.title("Ascending Score (FixationsDur / TotDuration)")
plt.xlabel("File (enumerated)")
plt.ylabel("Score")
plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig("ResidualProducts/Ascending_Score_Plot.jpg")
plt.show()

# Plot 2: Distribution of the number of rows
plt.figure(figsize=(10, 6))
plt.hist(results_df["Score"], bins=30, edgecolor='black', alpha=0.7)
plt.title("Distribution of Score (FixationsDur / TotDuration)")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.savefig("ResidualProducts/Score_Distribution.jpg")
plt.show()

# %%
length = len(results_df)
ran_05 = int(length*0.05)
results_df = results_df[ran_05:]
dfmin = results_df['Score'].min()
dfmax = results_df['Score'].max()
dfmean = results_df['Score'].mean()
dfstd = results_df['Score'].std()
print(f'Min: {dfmin}\nMax: {dfmax}\nMean: {dfmean}\nStd: {dfstd}')

results_df.to_csv("ResidualProducts/SelectedForMachineLearning.csv")
# Out:
# Min: 0.1649016641452345
# Max: 0.9987285441830897
# Mean: 0.6276332049648174
# Std: 0.23805055338108866

# %%
folder_path = "ResidualProducts/Fixations-PreProcessing/"

# Initialize an empty list to store the extracted features
final_features = []

# Name of the CSV file containing the selected trials
selected_csv = 'ResidualProducts/SelectedForMachineLearning.csv'

# Read the CSV file into a DataFrame
selected_df = pd.read_csv(selected_csv)

# Extract 'ID' and 'PAINTING' from the 'File' column using regex
selected_df['ID'] = selected_df['File'].apply(lambda x: int(re.search(r'S(\d+)_Q(\d+)\.csv', x).group(1)))
selected_df['PAINTING'] = selected_df['File'].apply(lambda x: int(re.search(r'S(\d+)_Q(\d+)\.csv', x).group(2)))

# Keep only the 'ID' and 'PAINTING' columns
selected_df = selected_df[['ID', 'PAINTING']]

# Print the number of rows in the DataFrame
print(len(selected_df))

# Iterate through each (ID, PAINTING) pair in the DataFrame
for _, row in selected_df.iterrows():
    s = row['ID']  # Extract the ID
    q = row['PAINTING']  # Extract the PAINTING

    # Construct the File for the corresponding trial
    file_name = f"{folder_path}S{s}_Q{q}.csv"
    try:
        # Read the trial data from the CSV file
        trial_data = pd.read_csv(file_name)

        # Extract features using the defined functions
        static_gaze_features = extract_static_gaze_features(trial_data)
        static_pupil_features = extract_static_pupil_features(trial_data)
        dynamic_gaze_features = extract_dynamic_gaze_features(trial_data)

        # Combine all extracted features into a single dictionary
        combined_features = {
            "ID": s,  # Include the ID
            "PAINTING": q,  # Include the PAINTING
            **static_gaze_features,  # Add static gaze features
            **static_pupil_features,  # Add static pupil features
            **dynamic_gaze_features  # Add dynamic gaze features
        }

        # Append the combined features to the final features list
        final_features.append(combined_features)

        # Print the progress for the current trial
        print(f'{s},{q}')

    # Handle exceptions if the file processing fails
    except Exception as e:
        print(f'{s},{q} failed: {e}')

# Convert the final features list into a DataFrame
final_dataset = pd.DataFrame(final_features)

# Save the final dataset to a CSV file
final_dataset.to_csv("ResidualProducts/final_features_dataset.csv", index=False)
# Out:
# 2554
# 278,10
# 277,23
# 204,9
# 337,20
# 277,18
# 77,10
# 376,6
# 199,1
# 211,20
# 8,47
# 204,4
# 277,1
# 166,4
# 193,1
# 85,11
# 2,1
# 77,6
# 198,15
# 206,22
# 170,4
# 147,10
# 2,20
# 199,4
# 85,15
# 295,4
# 1,4
# 175,10
# 394,20
# 8,13
# 88,2
# 376,21
# 165,4
# 28,20
# 345,13
# 119,15
# 394,47
# 7,4
# 121,10
# 207,20
# 121,7
# 198,11
# 413,21
# 8,21
# 277,6
# 28,18
# 175,21
# 28,22
# 326,18
# 193,21
# 175,13
# 193,14
# 216,15
# 371,1
# 175,23
# 54,18
# 204,18
# 198,47
# 345,20
# 77,22
# 170,11
# 204,11
# 184,15
# 121,20
# 174,20
# 175,4
# 127,10
# 7,47
# 278,7
# 278,23
# 200,47
# 85,6
# 330,23
# 2,14
# 389,20
# 197,9
# 389,6
# 110,20
# 337,21
# 211,15
# 311,15
# 183,20
# 26,11
# 326,23
# 193,10
# 204,2
# 376,4
# 198,23
# 194,47
# 295,22
# 183,23
# 256,13
# 8,7
# 198,14
# 330,14
# 193,15
# 85,22
# 206,18
# 170,1
# 9,7
# 257,47
# 8,23
# 193,22
# 211,23
# 216,20
# 244,22
# 337,6
# 125,21
# 170,6
# 7,16
# 85,7
# 337,15
# 194,23
# 8,1
# 271,47
# 88,16
# 159,16
# 198,16
# 57,23
# 345,18
# 311,9
# 326,14
# 215,10
# 199,6
# 127,23
# 9,9
# 119,20
# 119,9
# 394,23
# 193,23
# 277,2
# 199,14
# 170,20
# 345,47
# 216,4
# 147,22
# 132,20
# 183,7
# 216,6
# 215,14
# 337,11
# 175,15
# 49,2
# 216,47
# 57,18
# 387,15
# 7,7
# 91,15
# 7,15
# 345,6
# 7,13
# 57,6
# 215,16
# 277,4
# 37,4
# 270,21
# 216,7
# 389,13
# 159,4
# 85,23
# 147,20
# 166,7
# 174,6
# 198,13
# 77,4
# 165,23
# 170,13
# 389,7
# 28,23
# 165,9
# 147,16
# 175,7
# 337,22
# 132,14
# 200,4
# 376,18
# 127,7
# 162,7
# 111,9
# 26,6
# 6,20
# 124,16
# 175,2
# 376,14
# 121,23
# 85,20
# 166,21
# 215,21
# 26,20
# 127,9
# 131,20
# 183,18
# 199,23
# 337,9
# 77,13
# 57,20
# 207,13
# 124,11
# 326,22
# 170,9
# 198,21
# 197,6
# 285,9
# 311,20
# 410,1
# 345,11
# 377,15
# 199,11
# 165,20
# 197,7
# 170,7
# 206,9
# 193,2
# 371,4
# 271,15
# 52,6
# 221,47
# 170,47
# 256,4
# 7,10
# 162,20
# 121,47
# 244,20
# 59,23
# 229,18
# 27,20
# 205,6
# 351,7
# 217,22
# 310,22
# 229,6
# 139,22
# 291,22
# 351,23
# 222,21
# 310,11
# 229,21
# 204,16
# 124,2
# 229,11
# 310,1
# 351,21
# 229,4
# 351,16
# 310,21

# %%
# Define the paths to the input files
features_file = "ResidualProducts/final_features_dataset.csv"
votes_file = "votes_dataset.csv"

# Load the datasets
features_df = pd.read_csv(features_file)
votes_df = pd.read_csv(votes_file)

# Merge the datasets on the common columns 'ID' and 'PAINTING'
mapped_df = pd.merge(features_df, votes_df, on=["ID", "PAINTING"], how="inner")

# Save the merged dataset to a new CSV file
mapped_df.to_csv("ResidualProducts/ID-Features-Vote.csv", index=False)

print("CSV file 'ID-Features-Vote.csv' created successfully!")
# Out:
# CSV file 'ID-Features-Vote.csv' created successfully!

# %%
file_path = 'ResidualProducts/ID-Features-Vote.csv'
data = pd.read_csv(file_path)

# If vote value exists
if 'vote' in data.columns:
    # Histogram
    plt.hist(data['vote'], bins=range(0, 51, 1), edgecolor='black')
    plt.title('Votes Distribution')
    plt.xlabel('Vote')
    plt.ylabel('Frequency')
    plt.grid(axis='y', alpha=0.75)
    plt.savefig('ResidualProducts/Selected-Trials_Vote-Distribution.jpg')
    plt.show()
else:
    print("Column 'vote' doesn't exists.")

# %%
eliminated['ID'] = eliminated['File'].apply(lambda x: int(re.search(r'S(\d+)_Q(\d+)\.csv', x).group(1)))
eliminated['PAINTING'] = eliminated['File'].apply(lambda x: int(re.search(r'S(\d+)_Q(\d+)\.csv', x).group(2)))

mapped_eliminated = pd.merge(eliminated, votes_df, on=["ID", "PAINTING"], how="inner")


# If vote value exists
if 'vote' in mapped_eliminated.columns:
    # Histogram
    plt.hist(mapped_eliminated['vote'], bins=range(0, 51, 1), edgecolor='black')
    plt.title('Eliminated Trials Votes Distribution')
    plt.xlabel('Vote')
    plt.ylabel('Frequency')
    plt.grid(axis='y', alpha=0.75)
    plt.savefig('ResidualProducts/Eliminated-Trials_Vote-Distribution.jpg')
    plt.show()
else:
    print("Column 'vote' doesn't exists.")

# %%
final_dataset = pd.read_csv('ResidualProducts/ID-Features-Vote.csv')

# %%
# Exclude non-numeric columns like "ID" and "PAINTING"
numeric_features = final_dataset.drop(columns=["ID", "PAINTING", "vote"])

# Normalization with Min-Max Scaling (range 0-1)
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(numeric_features)

# Create a new DataFrame with scaled features
scaled_df = pd.DataFrame(scaled_features, columns=numeric_features.columns)

# Compute the variance of each scaled feature
feature_variance = scaled_df.var()

# Create a DataFrame for the variances
variance_df = pd.DataFrame({
    "Feature": feature_variance.index,
    "Variance": feature_variance.values
})

# Sort the DataFrame by variance in descending order
variance_df = variance_df.sort_values(by="Variance", ascending=False)

# Display the sorted DataFrame
print(variance_df)
variance_df.to_csv('ResidualProducts/variances.csv', index=False)

# Visualization with a bar chart
plt.figure(figsize=(10, 6))
plt.bar(variance_df["Feature"], variance_df["Variance"])
plt.xlabel("Features")
plt.ylabel("Variance (Scaled)")
plt.title("Feature Variance Across the Dataset (Scaled)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('ResidualProducts/VarianceChart.png')
plt.show()
# Out:
#                                      Feature  Variance
# 36   is_max_dilatation_in_last_instance_area  0.167921
# 17                    last_is_most_fixations  0.139552
# 16                  last_is_longest_duration  0.136669
# 15                   first_is_most_fixations  0.131332
# 14                 first_is_longest_duration  0.108461
# 35  is_max_dilatation_in_first_instance_area  0.084855
# 18                  total_duration_fixations  0.054420
# 6                         area_duration_mean  0.051820
# 1                          areas_of_interest  0.040318
# 23                            min_dilatation  0.036199
# 12                      last_series_duration  0.033583
# 5                          area_duration_max  0.031009
# 4                          area_duration_min  0.030928
# 28         instance_area_mean_dilatation_max  0.030896
# 24                            max_dilatation  0.028805
# 40         initial_instance_area_duration_ms  0.028691
# 25                           mean_dilatation  0.028320
# 29        instance_area_mean_dilatation_mean  0.028157
# 8                     min_fixations_per_area  0.028044
# 38             times_returns_to_initial_area  0.025634
# 32                      dilatation_range_max  0.025298
# 27         instance_area_mean_dilatation_min  0.024548
# 41         initial_instance_area_n_fixations  0.023273
# 13                 last_series_num_fixations  0.023066
# 7                          area_duration_std  0.022760
# 9                     max_fixations_per_area  0.022457
# 0                            total_fixations  0.021684
# 10                   mean_fixations_per_area  0.021470
# 26                            std_dilatation  0.021257
# 2                       visits_to_final_area  0.020065
# 11                    std_fixations_per_area  0.017930
# 34                      dilatation_range_std  0.016662
# 3                         isolated_fixations  0.016395
# 20                     fixation_duration_max  0.009742
# 39     n_area_changes_before_first_long_area  0.009687
# 33                     dilatation_range_mean  0.008314
# 37                   returns_to_initial_area  0.008158
# 21                    fixation_duration_mean  0.006964
# 22                     fixation_duration_std  0.006162
# 30         instance_area_mean_dilatation_std  0.004901
# 31                      dilatation_range_min  0.003902
# 19                     fixation_duration_min  0.000541

# %%
# Use the final dataset as the source
features_df = final_dataset

# Exclude the ID and PAINTING columns from analysis
columns_to_analyze = [col for col in features_df.columns if col not in ['ID', 'PAINTING']]

# List to store the results
results = []

# Calculate statistics for each column
for col in columns_to_analyze:
    feature_data = features_df[col].dropna()  # Remove NaN values
    min_val = feature_data.min()  # Minimum value
    max_val = feature_data.max()  # Maximum value
    mean_val = feature_data.mean()  # Mean value
    std_val = feature_data.std()  # Standard deviation
    var_val = feature_data.var()  # Variance
    
    # Perform Shapiro-Wilk normality test
    try:
        shapiro_stat, shapiro_p = shapiro(feature_data)
        normality = 'Normal' if shapiro_p > 0.05 else 'Not Normal'
    except ValueError:
        # Handle cases with insufficient data for the test
        shapiro_stat, shapiro_p, normality = None, None, 'Insufficient Data'

    # Add the results to the list
    results.append({
        'Feature': col,
        'Min': min_val,
        'Max': max_val,
        'Mean': mean_val,
        'Std': std_val,
        'Variance': var_val,
        'Shapiro-Wilk Stat': shapiro_stat,
        'Shapiro-Wilk p-value': shapiro_p,
        'Normality': normality
    })

# Create a DataFrame from the results
stats_df = pd.DataFrame(results)

# Save the results to a new CSV file
stats_df.to_csv('ResidualProducts/features_statistics.csv', index=False)

print("Analysis complete. Results saved to 'features_statistics.csv'.")
# Out:
# Analysis complete. Results saved to 'features_statistics.csv'.
